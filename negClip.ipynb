# %%
import nltk
import spacy
from tqdm import tqdm

# %%
nlp = spacy.load('en_core_web_lg')

# %%
from nltk.parse.stanford import StanfordParser

# Note: Download Stanford jar dependencies first
# See https://stackoverflow.com/questions/13883277/stanford-parser-and-nltk
stanford_parser = StanfordParser(
    model_path="edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz"
)

def nltk_stanford_tree(sent):
    """
    Visualize the Stanford dependency tree with nltk.tree
    """
    parse = stanford_parser.raw_parse(sent)

# %%
from nltk import word_tokenize
import pandas as pd

# %%
f1=u'this is my random text'

tokens = word_tokenize(f1)
bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(tokens)
bigram_freq = bigramFinder.ngram_fd.items()
bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)
print(bigramFreqTable)

def rightTypes(ngram):
    first_type = ('JJ')
    second_type = ('NN')
    tags = nltk.pos_tag(ngram)
    if tags[0][1] in first_type and tags[1][1] in second_type:
        return True
    else:
        return False

filtered_bi = bigramFreqTable[bigramFreqTable.bigram.map(lambda x: rightTypes(x))]
print(filtered_bi)
# Out:
#            bigram  freq
# 0      (this, is)     1
# 1        (is, my)     1
# 2    (my, random)     1
# 3  (random, text)     1
# Empty DataFrame
# Columns: [bigram, freq]
# Index: []

# %%
from datasets import load_dataset
auth_token = "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"  # Replace with an auth token, which you can get from your huggingface account: Profile -> Settings -> Access Tokens -> New Token
winoground = load_dataset("facebook/winoground", use_auth_token=auth_token)["test"]
winoground.set_format("torch")
def transform_wino(examples):
    examples["image_0"] = [image.convert("RGB") for image in examples["image_0"]]
    examples["image_1"] = [image.convert("RGB") for image in examples["image_1"]]
    return examples

winoground.set_transform(transform_wino)
device = 'cuda:0'
# Out:
# Found cached dataset winoground (/home/asura/.cache/huggingface/datasets/facebook___winoground/default/0.0.0/72585f4d9cd5a28790bb9bc2adbdd45633f36dfbf85df529e0756e114e134285)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from itertools import permutations, combinations

def swap_subtrees_between_verbs(doc):
    pass
    # verb_indices = []
    # for i, token in enumerate(doc):
    #     if token.pos_ in ['VERB']:
    #         # swap nsubj and dobj subtrees
    #         for child in token.children:
    #             print(child, child.dep_)
    #             if child.dep_ == 'nsubj':
    #                 child.dep_ = 'dobj'
    #             elif child.dep_ == 'dobj':
    #                 child.dep_ = 'nsubj'

    from nltk.tree import Tree

    def token_format(token):
        return "_".join([token.orth_, token.tag_, token.dep_])

    def to_nltk_tree(node):
        if node.n_lefts + node.n_rights > 0:
            return Tree(token_format(node),
                    [to_nltk_tree(child) 
                        for child in node.children]
                )
        else:
            return token_format(node)

    tree = [to_nltk_tree(sent.root) for sent in doc.sents]
    # The first item in the list is the full tree
    tree[0].draw()

    return doc


def swap_adjectives(doc: spacy.tokens.doc.Doc, neg: bool = False):
    adjpropn_pos = []
    adjpropn_words = []
    token_list = [token for token in doc]
    for i, token in enumerate(doc):
        cond = (not neg) and (token.pos_ in ['ADJ','PROPN'])
        ncond = neg and (token.pos_ not in ['ADJ','PROPN'])
        if cond or ncond:
            adjpropn_pos.append(i)
            adjpropn_words.append(token)

    # permute the words list completely
    perms = list(permutations(adjpropn_words))
    sentences = []
    for perm in perms:
        # fill out all the tokens
        new_token_list = token_list
        for i, pos in enumerate(adjpropn_pos):
            new_token_list[pos] = perm[i]
        sentences.append(new_token_list.copy())
    return sentences

def swap_adj_noun(doc):
    # swap combinations of adjectives and nouns with each other
    adj_noun_pos = []
    adj_noun_words = []
    token_list = [token for token in doc]
    for i, token in enumerate(doc):
        if token.pos_ in ['NOUN']:
            # find its noun chunk
            for chunk in doc.noun_chunks:
                if token in chunk:
                    adj_noun_pos.append((chunk.start, chunk.end))
    # get all nC2 2-choices of swaps from adj_noun_pos
    swaps = list(combinations(adj_noun_pos, 2))
    sentences = []
    # create temp token list
    for i,j in swaps:
        token_list = [token for token in doc]
        # swap the ranges
        token_list[i[0]:i[1]], token_list[j[0]:j[1]] = token_list[j[0]:j[1]], token_list[i[0]:i[1]]

        sentences.append(token_list.copy())
    return sentences

def swap_nodes_preposition(doc):
    # swap only the words across prepositions
    sentences = []
    indices_to_swap = []

    for token in doc:
        arg1, arg2 = None, None
        if token.pos_ in ['ADP']:
            for child in token.children:
                if child.dep_ == 'pobj':
                    # get noun chunks for child
                    for chunk in doc.noun_chunks:
                        if child in chunk:
                            arg1 = chunk.start, chunk.end
                            break

            if token.head.pos_ in ['NOUN', 'PROPN']:
                # get noun chunks for head
                for chunk in doc.noun_chunks:
                    if token.head in chunk:
                        arg2 = chunk.start, chunk.end
                        break
                        
            elif token.head.pos_ == 'VERB':
                for child in token.head.children:
                    if child.dep_ == 'nsubj':
                        for chunk in doc.noun_chunks:
                            if child in chunk:
                                arg2 = chunk.start, chunk.end
                                break
                                
            if arg1 and arg2:
                indices_to_swap.append((arg1, arg2))

    swaps = indices_to_swap
    # create temp token list
    for i, j in swaps:
        token_list = [token for token in doc]
        # swap the ranges
        token_list[i[0]:i[1]], token_list[j[0]:j[1]] = token_list[j[0]:j[1]], token_list[i[0]:i[1]]
        
        sentences.append(token_list.copy())
    return sentences

# %%
# run all functions on winoground captions
augmented_caption = {}
for i, example in tqdm(enumerate(winoground), total=len(winoground)):
    # get the caption
    caption_0 = example['caption_0']
    caption_1 = example['caption_1']

    # get the doc
    doc = nlp(caption_0)
    doc_1 = nlp(caption_1)
    # swap adjectives
    adj_swaps = swap_adjectives(doc, False)

    # swap nodes across prepositions
    preposition_swaps = swap_nodes_preposition(doc)
    # swap adj-noun
    adj_noun_swaps = swap_adj_noun(doc)
    
    # convert all types of swaps to tuples
    adj_swaps = [tuple(swap) for swap in adj_swaps]
    preposition_swaps = [tuple(swap) for swap in preposition_swaps]
    adj_noun_swaps = [tuple(swap) for swap in adj_noun_swaps]

    # create a set of all swaps
    all_swaps = set(adj_swaps + preposition_swaps + adj_noun_swaps)
    
    def filter_edit_distance(swaps):
        # filter with edit distance > 3
        print(len(swaps))
        return [swap for swap in swaps
                if nltk.edit_distance(' '.join([token.text for token in swap]), 
                                      ' '.join([token.text for token in doc])) > 3]
    

    def filter_set_with_alt_caption(all_swaps):
        return [" ".join([token.text for token in swap]) for swap in all_swaps
                if ([token.text for token in swap] != [token.text for token in doc_1]) and ([token.text for token in swap] != [token.text for token in doc])]+[" ".join([token.text for token in doc_1])]
    
    all_swaps = filter_set_with_alt_caption(all_swaps)
    # add to augmented caption
    augmented_caption[caption_0]= all_swaps
# Out:
# 100%|██████████| 400/400 [00:27<00:00, 14.37it/s]

# %%
augmented_caption
# Out:
# {'an old person kisses a young person': ['an young person kisses a old person',
#   'a young person kisses an old person'],
#  'the taller person hugs the shorter person': ['the shorter person hugs the taller person'],
#  'the masked wrestler hits the unmasked wrestler': ['the unmasked wrestler hits the masked wrestler'],
#  'a person watches an animal': ['an animal watches a person'],
#  'the person without earrings pays the person with earrings': ['earrings without earrings pays the person with earrings the person',
#   'the person without earrings pays earrings with earrings the person',
#   'earrings without the person pays the person with earrings',
#   'earrings without earrings pays the person with the person',
#   'earrings without earrings the person the person with earrings',
#   'the person without the person earrings person with earrings',
#   'the person with earrings pays the person without earrings'],
#  'a bird eats a snake': ['a snake eats a bird'],
#  'a plant was harmed by another organism, and that organism broke the plant into pieces': ['a plant was harmed by the plant , and that organism broke another organism into pieces',
#   'pieces was harmed by another organism , and that organism broke the plant into pieces a plant',
#   'organism was harmed by another organism , and that organism a plant the plant into pieces',
#   'a plant was harmed by another organism , and that the plant organism plant into pieces',
#   'the plant was harmed by another organism , and that organism broke a plant into pieces',
#   'a plant was harmed by organism , and that organism another organism the plant into pieces',
#   'a plant was harmed by another organism , and that pieces broke the plant into organism',
#   'a plant was harmed by pieces , and that organism broke the plant into pieces another organism',
#   'another organism was harmed by a plant , and that organism broke the plant into pieces',
#   'a plant was harmed by another organism , and that organism broke pieces into pieces the plant',
#   'another organism was harmed by a plant , and that plant broke the organism into pieces'],
#  'a bottle is in water': ['water is in water a bottle',
#   'water is in a bottle'],
#  'a tree smashed into a car': ['a car smashed into a tree'],
#  'people fall on the leaves': ['the leaves fall people leaves',
#   'the leaves fall on people'],
#  'the sail rests below the water': ['the water rests below the sail'],
#  'there is a table below someone': ['there is someone below a table'],
#  'the image shows a computer on top of books': ['books shows a computer on top of books the image',
#   'top shows a computer on the image of books',
#   'the image shows top on top a computer books',
#   'top shows a computer on top the image books',
#   'the image shows a computer on books of top',
#   'the image shows books on top of books a computer',
#   'a computer shows the image on top of books',
#   'the image shows books on top of a computer'],
#  'a caterpillar with some plants': ['some plants with a caterpillar',
#   'a plant with some caterpillars'],
#  'there is a mug in some grass': ['there is some grass in a mug'],
#  'there are more skiers than snowboarders': ['there are snowboarders than snowboarders more skiers',
#   'there are snowboarders than more skiers',
#   'there are more snowboarders than skiers'],
#  'there are fewer forks than spoons': ['there are spoons than fewer forks',
#   'there are spoons than spoons fewer forks',
#   'there are fewer spoons than forks'],
#  'there are more ladybugs than flowers': ['there are flowers than flowers more ladybugs',
#   'there are flowers than more ladybugs',
#   'there are more flowers than ladybugs'],
#  'there is less orange juice than milk': ['there is orange less juice than milk',
#   'there is milk than milk less orange juice',
#   'there is milk than less orange juice',
#   'there is less milk than orange juice'],
#  'there is more dirt than empty space in the jar': ['there is empty space than more dirt in the jar',
#   'there is more dirt than the jar in empty space',
#   'there is the jar than empty space in more dirt',
#   'there is empty dirt than more space in the jar',
#   'there is more empty space than dirt in the jar'],
#  'there is a bit less milk chocolate than white chocolate': ['there is white chocolate than white chocolate a bit less milk chocolate',
#   'there is white chocolate than a bit less milk chocolate',
#   'there is a bit white milk chocolate than less chocolate',
#   'there is a bit less white chocolate than milk chocolate'],
#  'a person sits and a dog stands': ['a dog sits and a person stands',
#   'a person stands and a dog sits'],
#  'The person with more facial hair lies awake while the other sleeps': ['The person with more other hair lies awake while the facial sleeps',
#   'more facial hair with The person lies awake while the other sleeps',
#   'The person with more awake hair lies facial while the other sleeps',
#   'more facial hair The person hair lies awake while the other sleeps',
#   'The person with more other hair lies facial while the awake sleeps',
#   'The person with more facial hair lies other while the awake sleeps',
#   'The person with more awake hair lies other while the facial sleeps',
#   'The person with more facial hair sleeps while the other lies awake'],
#  'the person in the middle is floating and some others are standing': ['some others in the middle is floating and the person are standing',
#   'the middle in the person is floating and some others are standing',
#   'the person in some others is floating and the middle are standing',
#   'the person in the middle is standing and some others are floating'],
#  'the person closer to the camera weightlifts and the person farther from the camera runs': ['weightlifts closer to the camera weightlifts the person the person farther from the camera runs',
#   'the person closer to weightlifts weightlifts the camera the person farther from the camera runs',
#   'the person closer to the person weightlifts and the camera farther from the camera runs',
#   'the person closer to the camera the person weightlifts person farther from the camera runs',
#   'the camera closer to the person weightlifts and the person farther from the camera runs',
#   'the person closer to the camera runs and the person farther from the camera weightlifts'],
#  'the person with the white collared shirt waters the plant while the other holds it': ['the person with the collared other shirt waters the plant while the white holds it',
#   'the plant with the white collared shirt waters the person while the other holds it',
#   'the person with the other white shirt waters the plant while the collared holds it',
#   'the person with the collared white shirt waters the plant while the other holds it',
#   'the white collared the person collared shirt waters the plant while the other holds it',
#   'the white collared shirt with the person waters the plant while the other holds it',
#   'the person with the plant waters the plant the white collared shirt other holds it',
#   'the person with the other collared shirt waters the plant while the white holds it',
#   'the person with the white other shirt waters the plant while the collared holds it',
#   'the person with the white collared shirt holds the plant while the other waters it'],
#  'the taller person chops food and the shorter person eats food': ['the shorter person chops food and the taller person eats food',
#   'the taller person chops the shorter food shorter person eats food',
#   'the taller person chops food and food eats food the shorter person',
#   'the shorter person chops food and the taller person eats food',
#   'food chops food and the shorter person eats food the taller person',
#   'food chops food and the taller person shorter person eats food',
#   'the taller person eats food and the shorter person chops food'],
#  'the person with the ponytail packs stuff and other buys it': ['the ponytail packs stuff with the person and other buys it',
#   'the ponytail packs the person packs stuff and other buys it',
#   'the person with the ponytail buys stuff and other packs it'],
#  'a person walking in a field of yellow flowers with a red dress': ['a person walking in yellow flowers of a field with a red dress',
#   'a person walking in a red dress of yellow flowers a field dress',
#   'a field walking in a person of yellow flowers with a red dress',
#   'yellow flowers walking in a field of a person with a red dress',
#   'a red dress walking in a field of yellow flowers a person dress',
#   'a person walking in a field of a red dress yellow flowers dress',
#   'a person walking in a field of red flowers with a yellow dress'],
#  'a brown dog is on a white couch': ['a white couch is on a brown dog',
#   'a white dog is on a brown couch'],
#  'a blue bird is next to a red berry': ['a red bird is blue to a next berry',
#   'a blue bird is red to a next berry',
#   'a red berry is next to a blue bird',
#   'a next bird is blue to a red berry',
#   'a next bird is red to a blue berry',
#   'a red bird is next to a blue berry'],
#  'The red book is above the yellow book and below the blue book': ['The red book is above the blue book and below the yellow book',
#   'the yellow book is above The red book and below the blue book',
#   'The yellow book is above the red book and below the blue book',
#   'The red book is above the blue book and below the yellow book',
#   'The blue book is above the red book and below the yellow book',
#   'the blue book is above the yellow book and below The red book',
#   'The blue book is above the yellow book and below the red book',
#   'The yellow book is above the blue book and below the red book'],
#  'astronauts in blue suits with a red planet in the background': ['blue suits in astronauts with a red planet in the background',
#   'the background in blue suits with a red planet astronauts background',
#   'astronauts in blue suits with the background in the a red planet',
#   'astronauts in a red planet blue suits planet in the background',
#   'a red planet in blue astronauts red planet in the background',
#   'a red planet in blue suits with astronauts in the background',
#   'astronauts in blue suits with the background in a red planet',
#   'astronauts in the background with a red planet in blue suits',
#   'blue suits astronauts suits with a red planet in the background',
#   'astronauts in red suits with a blue planet in the background'],
#  'the square table has a round base': ['a round base has the square table',
#   'the round table has a square base'],
#  'pointy bushes are behind rectangular bushes': ['rectangular bushes are behind pointy bushes'],
#  'a circular sign is above a rectangular sign': ['a rectangular sign is above a circular sign'],
#  'a wood chess piece rests on metal objects': ['metal objects rests on metal objects a wood chess piece',
#   'metal objects rests on a wood chess piece',
#   'a metal chess piece rests on wood objects'],
#  'soft shoes are on a smooth floor': ['a smooth floor are soft shoes floor',
#   'smooth shoes are on a soft floor'],
#  'the happy person is on the right and the sad person is on the left': ['the left person is on the right and the sad person is on the happy',
#   'the happy person is on the right and the left person is on the sad',
#   'the right is on the the happy person the sad person is on the left',
#   'the left person is on the right and the happy person is on the sad',
#   'the sad person is on the right and the left person is on the happy',
#   'the happy person is on the sad person the right person is on the left',
#   'the sad person is on the right and the happy person is on the left'],
#  'the hurt person is on the left and the helpful person is on the right': ['the hurt person is on the right and the helpful person is on the left',
#   'the left is on the the hurt person the helpful person is on the right',
#   'the right is on the left and the helpful person is on the the hurt person',
#   'the hurt person is on the left and the right is on the the helpful person',
#   'the hurt person is on the helpful person the left person is on the right',
#   'the helpful person is on the left and the hurt person is on the right'],
#  'the more content person has the healthier food and the less content person has the less healthy food': ['the more content person has the healthier food and the less healthy food has the less content person',
#   'the more content person has the healthy food and the less content person has the less healthier food',
#   'the more content person has the less content person the healthier food person has the less healthy food',
#   'the less healthy food has the healthier food and the less content person has the more content person',
#   'the healthier food has the the more content person the less content person has the less healthy food',
#   'the more content person has the less healthy food and the less content person the healthier food food',
#   'the less content person has the healthier food and the more content person has the less healthy food'],
#  'the orange lollipop is sad and the red lollipop is surprised': ['the orange lollipop is red and the surprised lollipop is sad',
#   'the red lollipop is sad and the surprised lollipop is orange',
#   'the orange lollipop is red and the sad lollipop is surprised',
#   'the surprised lollipop is red and the sad lollipop is orange',
#   'the sad lollipop is red and the surprised lollipop is orange',
#   'the red lollipop is surprised and the orange lollipop is sad',
#   'the orange lollipop is sad and the surprised lollipop is red',
#   'the red lollipop is orange and the surprised lollipop is sad',
#   'the sad lollipop is orange and the red lollipop is surprised',
#   'the sad lollipop is surprised and the orange lollipop is red',
#   'the red lollipop is sad and the orange lollipop is surprised',
#   'the red lollipop is sad and the orange lollipop is surprised',
#   'the surprised lollipop is red and the orange lollipop is sad',
#   'the sad lollipop is red and the orange lollipop is surprised',
#   'the surprised lollipop is orange and the red lollipop is sad',
#   'the sad lollipop is orange and the surprised lollipop is red',
#   'the surprised lollipop is orange and the sad lollipop is red',
#   'the red lollipop is orange and the sad lollipop is surprised',
#   'the sad lollipop is surprised and the red lollipop is orange',
#   'the surprised lollipop is sad and the red lollipop is orange',
#   'the orange lollipop is surprised and the sad lollipop is red',
#   'the surprised lollipop is sad and the orange lollipop is red',
#   'the red lollipop is surprised and the sad lollipop is orange',
#   'the orange lollipop is surprised and the red lollipop is sad'],
#  'the larger person wears yellow and the smaller person does not': ['the yellow person wears larger and the smaller person does not',
#   'the smaller person wears larger and the yellow person does not',
#   'the larger person wears smaller and the yellow person does not',
#   'the yellow person wears smaller and the larger person does not',
#   'the smaller person wears yellow and the larger person does not'],
#  'a big cat is next to a small dog': ['a next cat is big to a small dog',
#   'a small dog is next to a big cat',
#   'a big cat is small to a next dog',
#   'a small cat is big to a next dog',
#   'a next cat is small to a big dog',
#   'a small cat is next to a big dog'],
#  'the heavy oncoming traffic is contrasted with the light outgoing traffic': ['the light oncoming traffic is contrasted with the outgoing heavy traffic',
#   'the light heavy traffic is contrasted with the outgoing oncoming traffic',
#   'the oncoming light traffic is contrasted with the heavy outgoing traffic',
#   'the outgoing light traffic is contrasted with the oncoming heavy traffic',
#   'the oncoming outgoing traffic is contrasted with the light heavy traffic',
#   'the heavy outgoing traffic is contrasted with the oncoming light traffic',
#   'the outgoing light traffic is contrasted with the heavy oncoming traffic',
#   'the light outgoing traffic is contrasted with the oncoming heavy traffic',
#   'the oncoming heavy traffic is contrasted with the light outgoing traffic',
#   'the heavy oncoming traffic is contrasted with the outgoing light traffic',
#   'the light outgoing traffic is contrasted with the heavy oncoming traffic',
#   'the light outgoing traffic is contrasted with the heavy oncoming traffic',
#   'the heavy outgoing traffic is contrasted with the light oncoming traffic',
#   'the outgoing heavy traffic is contrasted with the oncoming light traffic',
#   'the oncoming heavy traffic is contrasted with the outgoing light traffic',
#   'the heavy light traffic is contrasted with the outgoing oncoming traffic',
#   'the outgoing oncoming traffic is contrasted with the heavy light traffic',
#   'the light heavy traffic is contrasted with the oncoming outgoing traffic',
#   'the heavy light traffic is contrasted with the oncoming outgoing traffic',
#   'the oncoming light traffic is contrasted with the outgoing heavy traffic',
#   'the outgoing oncoming traffic is contrasted with the light heavy traffic',
#   'the oncoming outgoing traffic is contrasted with the heavy light traffic',
#   'the outgoing heavy traffic is contrasted with the light oncoming traffic',
#   'the light oncoming traffic is contrasted with the heavy outgoing traffic'],
#  'a cold drink on a hot day': ['a hot day on a cold drink',
#   'a hot drink on a cold day'],
#  'a person is drinking now and eating later': ['a person is drinking later and eating now'],
#  'the sailboat sails close but the beach is far away': ['the beach sails close but the sailboat is far away',
#   'the sailboat sails far away but the beach is close'],
#  'the passenger is riding inattentive to the road and the driver is driving attentive to the road': ['the passenger is riding inattentive to the road and the road is driving attentive to the driver',
#   'the driver is riding inattentive to the road and the passenger is driving attentive to the road',
#   'the road is riding inattentive to the passenger and the driver is driving attentive to the road',
#   'the passenger is riding inattentive to the driver and the road is driving attentive to the road',
#   'the road is riding inattentive to the road and the driver is driving attentive to the passenger',
#   'the passenger is riding attentive to the road and the driver is driving inattentive to the road'],
#  "it wears a hat but the person doesn't": ["it wears the person but a hat does n't",
#   "the person wears a hat but it does n't"],
#  'the person with green legs is running quite slowly and the red legged one runs faster': ['green legs with the person is running quite slowly and the red legged one runs faster',
#   'the person with green legs is running quite slowly and the legged red one runs faster',
#   'the person with legged legs is running quite slowly and the green red one runs faster',
#   'the person with legged legs is running quite slowly and the red green one runs faster',
#   'the person with red legs is running quite slowly and the green legged one runs faster',
#   'the person with red legs is running quite slowly and the legged green one runs faster',
#   'the person with green legs is running faster and the red legged one runs quite slowly'],
#  'a person is in the water and close to the sand': ['a person is in the sand and close to the water',
#   'the water is in a person and close to the sand',
#   'the sand is in the water and close to a person',
#   'a person is close to the water and in the sand'],
#  'a frog is above rocks which are under the water': ['a frog is above the water which are rocks water',
#   'the water is above rocks which are under a frog',
#   'rocks is above rocks a frog are under the water',
#   'a frog is under rocks which are above the water'],
#  'driving off the road and on the unpaved terrain': ['driving off the unpaved terrain and the road terrain',
#   'driving on the road and off the unpaved terrain'],
#  'someone is in a helicopter with a car': ['someone is in a car with a helicopter',
#   'someone is with a helicopter in a car'],
#  'the green one can fit inside the blue one and the blue one can fit outside the green one': ['the green one can fit inside the green one and the blue one can fit outside the blue one',
#   'the blue one can fit inside the green one and the blue one can fit outside the green one',
#   'the blue one can fit inside the blue one and the green one can fit outside the green one',
#   'the blue one can fit inside the green one and the green one can fit outside the blue one',
#   'the blue one can fit inside the blue one and the green one can fit outside the green one',
#   'the blue one can fit inside the blue one and the green one can fit outside the green one',
#   'the green one can fit inside the green one and the blue one can fit outside the blue one',
#   'the blue one can fit inside the green one and the green one can fit outside the blue one',
#   'the blue one can fit inside the blue one and the green one can fit outside the green one',
#   'the blue one can fit inside the green one and the blue one can fit outside the green one',
#   'the green one can fit inside the blue one and the green one can fit outside the blue one',
#   'the green one can fit inside the green one and the blue one can fit outside the blue one',
#   'the green one can fit inside the blue one and the green one can fit outside the blue one',
#   'the green one can fit inside the green one and the blue one can fit outside the blue one',
#   'the blue one can fit inside the green one and the blue one can fit outside the green one',
#   'the blue one can fit inside the green one and the green one can fit outside the blue one',
#   'the blue one can fit inside the green one and the blue one can fit outside the green one',
#   'the green one can fit inside the blue one and the green one can fit outside the blue one',
#   'the blue one can fit inside the green one and the blue one can fit outside the green one',
#   'the green one can fit inside the blue one and the green one can fit outside the blue one',
#   'the green one can fit inside the blue one and the green one can fit outside the blue one',
#   'the green one can fit inside the green one and the blue one can fit outside the blue one',
#   'the blue one can fit inside the blue one and the green one can fit outside the green one',
#   'the blue one can fit inside the green one and the green one can fit outside the blue one',
#   'the green one can fit outside the blue one and the blue one can fit inside the green one'],
#  'jumping away from the photographer and towards the others': ['jumping away from the others and towards the photographer',
#   'jumping towards the photographer and away from the others'],
#  'someone bakes the dough before the dough is eaten': ['the dough is eaten before someone bakes the dough'],
#  'it hatched before it was eaten': ['it was eaten before it hatched'],
#  'there are three bananas and two apples': ['there are two apples and three bananas',
#   'there are two bananas and three apples'],
#  'someone has loaded their plate with one of the toast slices and two of the eggs': ['someone has loaded the eggs with one of the toast slices and two of their plate',
#   'someone has loaded their plate with one of the eggs and two of the the toast slices',
#   'someone has loaded the toast slices with one their plate slices and two of the eggs',
#   'someone has loaded their plate with two of the toast slices and one of the eggs'],
#  'there are three people and two windows': ['there are two windows and three people',
#   'there are two people and three windows'],
#  'there are 50 stars on the right flag and 5 stars on the left flag': ['there are 50 stars on the right flag and the left flag on 5 stars',
#   'there are 50 stars on 5 stars and 5 the right flag the left flag',
#   'there are 50 stars on the left flag and 5 stars on the right flag',
#   'there are the left flag on the right flag and 5 stars 50 stars flag',
#   'there are the right flag 50 stars flag and 5 stars on the left flag',
#   'there are 50 stars on the left flag and 5 stars on the right flag',
#   'there are the right flag on 50 stars and 5 stars on the left flag',
#   'there are 50 stars on the right flag and the left flag 5 stars flag',
#   'there are 5 stars on the right flag and 50 stars on the left flag'],
#  'no people wear blue shirts and six people wear white shirts': ['no people wear white shirts and six people wear blue shirts',
#   'blue shirts wear no people and six people wear white shirts',
#   'no people wear white shirts and six people wear blue shirts',
#   'white shirts wear blue shirts and six people wear no people',
#   'no people wear six people and blue shirts wear white shirts',
#   'no people wear blue shirts and white shirts wear six people',
#   'six people wear blue shirts and no people wear white shirts'],
#  "the dog's leg is on the person's torso": ["the person 's torso is on the dog 's leg",
#   "the person 's leg is on the dog 's torso"],
#  "the animal's eyes are bigger than the person's": ["the person are bigger than the person the animal 's eyes",
#   "the person 's eyes are bigger than the animal 's"],
#  "the taller person's arm is around the shorter person's shoulder": ["the shorter person 's shoulder is around the taller person 's arm",
#   "the shorter person 's arm is around the taller person 's shoulder"],
#  'the person in a brown coat looks back and the person in a black coat looks forward': ['a black coat in a brown coat looks back and the person the person coat looks forward',
#   'a brown coat in the person looks back and the person in a black coat looks forward',
#   'the person in a brown coat looks back and a black coat in the person looks forward',
#   'the person in a brown coat looks back and a black coat the person coat looks forward',
#   'a brown coat the person coat looks back and the person in a black coat looks forward',
#   'the person in the person looks back and the a brown coat a black coat looks forward',
#   'the person in a black coat looks back and the person in a brown coat looks forward'],
#  'it ran away while they pursued': ['they ran away while it pursued'],
#  'almost everyone is in a boat and one is swimming': ['almost everyone is in one and one a boat swimming',
#   'one is in a boat and almost everyone is swimming'],
#  "the person with the lighter shoes is holding an emoji and the person with the darker shoes isn't": ["the person with the lighter shoes is holding the person and an emoji with the darker shoes is n't",
#   "the person with the lighter shoes is holding an emoji and the darker shoes with the person is n't",
#   "an emoji with the lighter shoes is holding the person and the person with the darker shoes is n't",
#   "the person with the lighter shoes is holding an emoji and the darker shoes the person shoes is n't",
#   "the person with an emoji is holding an the lighter shoes the person with the darker shoes is n't",
#   "the lighter shoes the person shoes is holding an emoji and the person with the darker shoes is n't",
#   "the darker shoes with the lighter shoes is holding an emoji and the person the person shoes is n't",
#   "the lighter shoes with the person is holding an emoji and the person with the darker shoes is n't",
#   "the person with the person is holding an emoji and the the lighter shoes the darker shoes is n't",
#   "the person with the lighter shoes is holding the darker shoes and the person an emoji shoes is n't",
#   "the person with the darker shoes is holding an emoji and the person with the lighter shoes is n't"],
#  'the person wearing neutral colors poses and the person wearing brighter colors takes a picture': ['neutral colors poses the person poses and the person wearing brighter colors takes a picture',
#   'a picture wearing neutral colors poses and the person wearing brighter colors takes the person',
#   'the person wearing neutral colors poses and brighter colors wearing the person takes a picture',
#   'the person wearing the person and the neutral colors poses brighter colors takes a picture',
#   'brighter colors wearing neutral colors poses and the person wearing the person takes a picture',
#   'the person wearing a picture and the person wearing brighter colors takes a neutral colors poses',
#   'the person wearing neutral colors poses and the person wearing a picture takes brighter colors',
#   'the person wearing brighter colors and the person wearing brighter neutral colors poses a picture',
#   'the person wearing neutral colors poses and a picture wearing brighter colors takes the person',
#   'the person wearing brighter colors poses and the person wearing neutral colors takes a picture'],
#  "it's a fire truck": ["it 's a truck fire"],
#  'watching the present': ['presenting the watch'],
#  'walking out on a rock': ['rocking out on a walk'],
#  'the kid with the magnifying glass looks at them': ['them with the magnifying glass looks at the kid',
#   'the magnifying glass the kid glass looks at them',
#   'the magnifying glass with the kid looks at them',
#   'the kid looks at them with the magnifying glass'],
#  'the person with the kids is sitting': ['the kids with the person is sitting',
#   'the person is sitting with the kids'],
#  'the people with shoes are touching each other': ['shoes with the people are touching each other',
#   'shoes with shoes the people touching each other',
#   'the people are touching each other with shoes'],
#  'someone with an apple is hurt by a tree': ['someone with a tree is hurt by an apple',
#   'someone is hurt by a tree with an apple'],
#  'the person that is on the table is eating the food': ['the person that is on the food is eating the table',
#   'the table that is on the person is eating the food',
#   'the food that is on the table is eating the person',
#   'the person is eating the food that is on the table'],
#  'the watering can is larger than the pot': ['the pot can is larger than the watering',
#   'the pot is larger than the watering can'],
#  'they hold a suitcase handle with their left hand and they hold a passport with their right hand': ['they hold a suitcase handle with their right hand and they hold a passport with their left hand',
#   'they hold a suitcase handle with a passport and they hold a their left hand their right hand',
#   'they hold a passport with their left hand and they hold a a suitcase handle their right hand',
#   'they hold a suitcase handle with their left hand and their right hand hold a passport with they',
#   'they hold a suitcase handle with their left hand and they hold their right hand a passport hand',
#   'they hold their left hand with a suitcase handle and they hold a passport with their right hand',
#   'they hold their right hand with their left hand and they hold a passport with a suitcase handle',
#   'they hold a suitcase handle with their right hand and they hold a passport with their left hand',
#   'they hold a passport with their left hand and they hold a suitcase handle with their right hand'],
#  'the person with the patterned shirt is curly-haired and the other is straight-haired': ['the person with the haired shirt is patterned - straight and the haired is curly - other',
#   'the person with the other shirt is curly - patterned and the haired is straight - haired',
#   'the person with the straight shirt is patterned - curly and the haired is other - haired',
#   'the person with the curly shirt is haired - straight and the patterned is haired - other',
#   'the person with the curly shirt is haired - haired and the straight is other - patterned',
#   'the person with the haired shirt is curly - patterned and the haired is other - straight',
#   'the person with the patterned shirt is haired - other and the haired is curly - straight',
#   'the person with the straight shirt is haired - curly and the other is haired - patterned',
#   'the person with the haired shirt is haired - curly and the straight is other - patterned',
#   'the person with the straight shirt is haired - patterned and the haired is curly - other',
#   'the person with the straight shirt is haired - other and the patterned is haired - curly',
#   'the person with the haired shirt is straight - patterned and the haired is curly - other',
#   'the person with the straight shirt is patterned - haired and the curly is haired - other',
#   'the person with the straight shirt is haired - patterned and the curly is other - haired',
#   'the person with the patterned shirt is curly - other and the haired is haired - straight',
#   'the person with the haired shirt is haired - patterned and the straight is other - curly',
#   'the person with the haired shirt is straight - patterned and the curly is other - haired',
#   'the person with the haired shirt is other - haired and the curly is patterned - straight',
#   'the person with the curly shirt is haired - patterned and the other is haired - straight',
#   'the person with the patterned shirt is curly - straight and the other is haired - haired',
#   'the person with the straight shirt is curly - other and the haired is patterned - haired',
#   'the person with the other shirt is haired - patterned and the curly is straight - haired',
#   'the person with the patterned shirt is straight - haired and the curly is haired - other',
#   'the person with the haired shirt is patterned - curly and the haired is straight - other',
#   'the person with the haired shirt is haired - straight and the other is patterned - curly',
#   'the person with the patterned shirt is other - haired and the curly is straight - haired',
#   'the person with the curly shirt is other - straight and the haired is haired - patterned',
#   'the person with the curly shirt is patterned - haired and the straight is haired - other',
#   'the person with the patterned shirt is haired - curly and the other is haired - straight',
#   'the person with the patterned shirt is haired - other and the haired is curly - straight',
#   'the person with the curly shirt is haired - other and the straight is haired - patterned',
#   'the person with the haired shirt is straight - curly and the patterned is other - haired',
#   'the person with the haired shirt is other - patterned and the straight is haired - curly',
#   'the person with the curly shirt is other - haired and the haired is straight - patterned',
#   'the person with the curly shirt is straight - haired and the haired is other - patterned',
#   'the person with the haired shirt is patterned - straight and the haired is other - curly',
#   'the person with the patterned shirt is haired - other and the haired is straight - curly',
#   'the person with the other shirt is patterned - haired and the straight is curly - haired',
#   'the person with the haired shirt is patterned - haired and the straight is curly - other',
#   'the person with the other shirt is haired - curly and the straight is haired - patterned',
#   'the person with the patterned shirt is straight - curly and the haired is other - haired',
#   'the person with the patterned shirt is haired - curly and the straight is other - haired',
#   'the person with the haired shirt is haired - patterned and the other is straight - curly',
#   'the person with the other shirt is curly - patterned and the haired is straight - haired',
#   'the person with the haired shirt is straight - curly and the haired is patterned - other',
#   'the person with the haired shirt is patterned - curly and the other is straight - haired',
#   'the person with the straight shirt is haired - haired and the patterned is curly - other',
#   'the person with the other shirt is straight - curly and the patterned is haired - haired',
#   'the person with the other shirt is haired - straight and the curly is patterned - haired',
#   'the person with the straight shirt is haired - curly and the other is haired - patterned',
#   'the person with the straight shirt is other - haired and the patterned is curly - haired',
#   'the person with the curly shirt is patterned - other and the haired is haired - straight',
#   'the person with the curly shirt is patterned - straight and the haired is other - haired',
#   'the person with the other shirt is haired - patterned and the curly is haired - straight',
#   'the person with the haired shirt is patterned - other and the straight is curly - haired',
#   'the person with the haired shirt is haired - patterned and the other is curly - straight',
#   'the person with the patterned shirt is haired - other and the haired is straight - curly',
#   'the person with the other shirt is haired - curly and the haired is patterned - straight',
#   'the person with the straight shirt is patterned - haired and the other is curly - haired',
#   'the person with the haired shirt is patterned - haired and the straight is other - curly',
#   'the person with the curly shirt is straight - haired and the patterned is haired - other',
#   'the person with the patterned shirt is haired - haired and the curly is other - straight',
#   'the person with the haired shirt is other - haired and the patterned is curly - straight',
#   'the person with the haired shirt is curly - other and the patterned is haired - straight',
#   'the person with the patterned shirt is other - curly and the haired is straight - haired',
#   'the person with the curly shirt is haired - other and the haired is patterned - straight',
#   'the person with the haired shirt is other - patterned and the haired is straight - curly',
#   'the person with the patterned shirt is other - straight and the haired is curly - haired',
#   'the person with the curly shirt is other - patterned and the straight is haired - haired',
#   'the person with the straight shirt is other - haired and the patterned is curly - haired',
#   'the person with the other shirt is haired - haired and the patterned is curly - straight',
#   'the person with the straight shirt is haired - patterned and the other is haired - curly',
#   'the person with the straight shirt is haired - haired and the patterned is other - curly',
#   'the person with the curly shirt is other - haired and the patterned is haired - straight',
#   'the person with the haired shirt is haired - curly and the straight is other - patterned',
#   'the person with the haired shirt is other - haired and the patterned is curly - straight',
#   'the person with the patterned shirt is curly - other and the straight is haired - haired',
#   'the person with the haired shirt is curly - other and the haired is straight - patterned',
#   'the person with the haired shirt is haired - other and the patterned is straight - curly',
#   'the person with the haired shirt is haired - other and the straight is curly - patterned',
#   'the person with the haired shirt is curly - straight and the haired is other - patterned',
#   'the person with the other shirt is haired - haired and the curly is patterned - straight',
#   'the person with the straight shirt is other - curly and the haired is patterned - haired',
#   'the person with the straight shirt is haired - curly and the haired is patterned - other',
#   'the person with the patterned shirt is straight - curly and the haired is haired - other',
#   'the person with the patterned shirt is curly - other and the haired is haired - straight',
#   'the person with the patterned shirt is other - haired and the haired is straight - curly',
#   'the person with the patterned shirt is straight - haired and the haired is curly - other',
#   'the person with the straight shirt is curly - patterned and the haired is haired - other',
#   'the person with the haired shirt is haired - curly and the other is straight - patterned',
#   'the person with the straight shirt is patterned - curly and the other is haired - haired',
#   'the person with the haired shirt is haired - other and the patterned is curly - straight',
#   'the person with the haired shirt is haired - patterned and the curly is straight - other',
#   'the person with the straight shirt is curly - haired and the patterned is haired - other',
#   'the person with the haired shirt is haired - curly and the patterned is other - straight',
#   'the person with the curly shirt is patterned - haired and the other is haired - straight',
#   'the person with the straight shirt is haired - patterned and the haired is other - curly',
#   'the person with the haired shirt is other - curly and the patterned is haired - straight',
#   'the person with the curly shirt is straight - other and the haired is patterned - haired',
#   'the person with the curly shirt is haired - straight and the haired is patterned - other',
#   'the person with the curly shirt is other - haired and the straight is haired - patterned',
#   'the person with the straight shirt is patterned - haired and the haired is curly - other',
#   'the person with the curly shirt is haired - straight and the haired is other - patterned',
#   'the person with the curly shirt is haired - straight and the haired is other - patterned',
#   'the person with the haired shirt is straight - other and the curly is patterned - haired',
#   'the person with the other shirt is curly - haired and the haired is patterned - straight',
#   'the person with the haired shirt is haired - other and the curly is straight - patterned',
#   'the person with the other shirt is straight - haired and the curly is haired - patterned',
#   'the person with the patterned shirt is haired - curly and the haired is other - straight',
#   'the person with the haired shirt is haired - straight and the curly is patterned - other',
#   'the person with the patterned shirt is haired - other and the curly is haired - straight',
#   'the person with the curly shirt is patterned - haired and the haired is straight - other',
#   'the person with the haired shirt is curly - straight and the haired is other - patterned',
#   'the person with the curly shirt is haired - haired and the other is patterned - straight',
#   'the person with the haired shirt is patterned - straight and the curly is other - haired',
#   'the person with the other shirt is haired - haired and the patterned is straight - curly',
#   'the person with the straight shirt is haired - haired and the curly is other - patterned',
#   'the person with the haired shirt is patterned - other and the curly is haired - straight',
#   'the person with the curly shirt is patterned - other and the haired is straight - haired',
#   'the person with the straight shirt is curly - other and the haired is haired - patterned',
#   'the person with the patterned shirt is curly - straight and the haired is haired - other',
#   'the person with the haired shirt is other - curly and the straight is haired - patterned',
#   'the person with the haired shirt is other - haired and the straight is curly - patterned',
#   'the person with the haired shirt is haired - straight and the patterned is curly - other',
#   'the person with the patterned shirt is straight - haired and the curly is other - haired',
#   'the person with the patterned shirt is curly - haired and the haired is other - straight',
#   'the person with the haired shirt is straight - other and the curly is patterned - haired',
#   'the person with the other shirt is straight - haired and the patterned is haired - curly',
#   'the person with the patterned shirt is other - straight and the haired is curly - haired',
#   'the person with the straight shirt is patterned - haired and the haired is curly - other',
#   'the person with the other shirt is patterned - straight and the haired is haired - curly',
#   'the person with the other shirt is straight - curly and the haired is patterned - haired',
#   'the person with the straight shirt is haired - haired and the curly is other - patterned',
#   'the person with the other shirt is haired - patterned and the straight is haired - curly',
#   'the person with the haired shirt is haired - straight and the other is curly - patterned',
#   'the person with the patterned shirt is haired - other and the curly is haired - straight',
#   'the person with the curly shirt is straight - patterned and the haired is haired - other',
#   'the person with the haired shirt is haired - straight and the curly is patterned - other',
#   'the person with the haired shirt is haired - straight and the curly is other - patterned',
#   'the person with the patterned shirt is other - straight and the curly is haired - haired',
#   'the person with the other shirt is patterned - haired and the straight is haired - curly',
#   'the person with the straight shirt is patterned - haired and the haired is other - curly',
#   'the person with the patterned shirt is haired - curly and the other is haired - straight',
#   'the person with the other shirt is patterned - haired and the haired is straight - curly',
#   'the person with the patterned shirt is other - straight and the haired is haired - curly',
#   'the person with the straight shirt is other - haired and the curly is patterned - haired',
#   'the person with the haired shirt is straight - curly and the haired is patterned - other',
#   'the person with the haired shirt is straight - curly and the haired is other - patterned',
#   'the person with the patterned shirt is other - haired and the curly is haired - straight',
#   'the person with the patterned shirt is straight - other and the haired is curly - haired',
#   'the person with the straight shirt is other - patterned and the haired is haired - curly',
#   'the person with the patterned shirt is haired - straight and the haired is curly - other',
#   'the person with the other shirt is straight - haired and the curly is haired - patterned',
#   'the person with the haired shirt is other - patterned and the haired is straight - curly',
#   'the person with the haired shirt is haired - other and the patterned is straight - curly',
#   'the person with the haired shirt is straight - curly and the patterned is haired - other',
#   'the person with the other shirt is curly - haired and the haired is patterned - straight',
#   'the person with the patterned shirt is other - haired and the curly is straight - haired',
#   'the person with the curly shirt is other - straight and the haired is patterned - haired',
#   'the person with the other shirt is haired - patterned and the straight is haired - curly',
#   'the person with the straight shirt is curly - haired and the other is patterned - haired',
#   'the person with the patterned shirt is straight - curly and the other is haired - haired',
#   'the person with the curly shirt is straight - haired and the other is haired - patterned',
#   'the person with the haired shirt is other - patterned and the haired is curly - straight',
#   'the person with the other shirt is curly - straight and the haired is patterned - haired',
#   'the person with the curly shirt is haired - patterned and the other is straight - haired',
#   'the person with the haired shirt is straight - haired and the other is curly - patterned',
#   'the person with the curly shirt is straight - patterned and the other is haired - haired',
#   'the person with the other shirt is haired - haired and the straight is curly - patterned',
#   'the person with the haired shirt is straight - other and the curly is haired - patterned',
#   'the person with the haired shirt is curly - straight and the patterned is other - haired',
#   'the person with the patterned shirt is straight - haired and the haired is other - curly',
#   'the person with the curly shirt is haired - haired and the straight is patterned - other',
#   'the person with the patterned shirt is haired - haired and the straight is curly - other',
#   'the person with the straight shirt is haired - other and the patterned is curly - haired',
#   'the person with the haired shirt is patterned - curly and the other is haired - straight',
#   'the person with the patterned shirt is haired - haired and the straight is curly - other',
#   'the person with the straight shirt is other - haired and the haired is patterned - curly',
#   'the person with the curly shirt is straight - haired and the patterned is haired - other',
#   'the person with the other shirt is patterned - straight and the haired is curly - haired',
#   'the person with the haired shirt is haired - curly and the straight is patterned - other',
#   'the person with the other shirt is curly - patterned and the straight is haired - haired',
#   'the person with the patterned shirt is haired - curly and the straight is other - haired',
# ...
#   'two people wearing clothes of the different colors are on same side of the tennis net',
#   'clothes wearing clothes two people the same colors are on different side of the tennis net',
#   'two people wearing clothes of different side are on different the same colors the tennis net',
#   'two people wearing different side of the same colors are clothes side of the tennis net',
#   'two people wearing the same colors of clothes are on different side of the tennis net',
#   'two people wearing the same clothes same colors are on different side of the tennis net',
#   'two people wearing clothes of the tennis net are on different side of the same colors',
#   'two people wearing clothes of different colors are on the same side of the tennis net'],
#  'living things drinking': ['drinking living things'],
#  'a person near water using a lasso': ['water near water a person a lasso',
#   'water near a person using a lasso',
#   'a person near a lasso water lasso',
#   'a lasso near water using a person',
#   'near a person using a water lasso'],
#  'a person spraying water on someone else and a person on a bike': ['water spraying water a person someone else and a person on a bike',
#   'a bike spraying water on someone else and a person on a person',
#   'a person spraying a person on someone else water person on a bike',
#   'a person spraying water on someone else and a bike on a person',
#   'a person spraying a bike on someone else and a person water bike',
#   'a person spraying water on a person on a bike and someone else'],
#  'a person stretching behind a brown dog': ['a brown dog stretching a person dog',
#   'a brown dog stretching behind a person'],
#  'a person carrying more than one flotation device': ['more than one a person one flotation device',
#   'more than one flotation device carrying a person'],
#  'two kids on a pool floatie and one kid swimming': ['a pool floatie two kids floatie and one kid swimming',
#   'a pool floatie on two kids and one kid swimming',
#   'two kids on one kid and one a pool floatie',
#   'one kid on a pool floatie and two kids swimming'],
#  'gears for moving something': ['moving gears for something'],
#  'looking from above at a collection of similar objects below': ['looking from above at similar objects of a collection below',
#   'looking from below at a collection of similar objects above'],
#  'a toy herbivore stands on top of at least one toy carnivore': ['a toy herbivore stands on at least one toy of top carnivore',
#   'top stands on a toy herbivore of at least one toy carnivore',
#   'at least one toy stands on top a toy herbivore toy carnivore',
#   'a toy herbivore stands on at least top least one toy carnivore',
#   'top stands on top of a toy herbivore least one toy carnivore',
#   'at least one toy herbivore stands on top of a toy carnivore'],
#  'a person supports a small chair': ['a small chair a person chair',
#   'a chair supports a small person'],
#  'a person smiles at another person wearing a checked shirt who is hitting a ping pong ball': ['a person smiles at another person wearing a ping pong ball who is a checked shirt ball',
#   'another person smiles at a person wearing a checked shirt who is hitting a ping pong ball',
#   'a checked shirt smiles at another person a person shirt who is hitting a ping pong ball',
#   'a ping pong ball smiles at another person wearing a checked shirt who a person pong ball',
#   'a person smiles at a checked shirt another person shirt who is hitting a ping pong ball',
#   'a person smiles at a ping pong ball wearing a checked shirt who another person pong ball',
#   'a person wearing a checked shirt smiles at another person who is hitting a ping pong ball'],
#  'two versions of one person': ['one person of two versions',
#   'one version of two persons'],
#  'There are not pink flowers below the bird with yellow head feathers': ['There are not the bird below pink flowers with yellow head feathers',
#   'There are not pink flowers below yellow head feathers the bird feathers',
#   'There are not yellow flowers below the bird with pink head feathers',
#   'There are not yellow head feathers below the bird pink flowers feathers',
#   'There are not yellow head feathers below the bird with pink flowers',
#   'There are pink flowers not below the bird with yellow head feathers'],
#  'In a shopping cart, there are two animals that are the same species but are looking in different directions': ['In a shopping cart , there are two animals that are different directions but are looking in different the same species',
#   'In two animals , there are two a shopping cart are the same species but are looking in different directions',
#   'In a shopping cart , there are different directions that are the same species but are looking in two animals',
#   'In a shopping cart , there are the same species that two animals species but are looking in different directions',
#   'In the same species , there are two animals that are a shopping cart but are looking in different directions',
#   'In different directions , there are two animals that are the same species but are looking in different a shopping cart',
#   'In a shopping cart , there are two animals that are the different species but are looking in same directions'],
#  'water is on and under a vessel': ['a vessel is on and water vessel',
#   'a vessel is on and under water'],
#  'two bodies share with one head': ['one head share with two bodies',
#   'one bodies share with two head'],
#  'The worker wears something striped over a white undershirt with a collar': ['The worker wears something striped over a collar with a a white undershirt',
#   'The worker wears something striped over a collar with a white undershirt',
#   'a collar wears something striped over a white undershirt with The worker',
#   'a white undershirt wears something striped The worker undershirt with a collar',
#   'The worker wears something white over a striped undershirt with a collar'],
#  'A person seen from above has a grid below them': ['a grid seen from above has A person below them',
#   'A person seen from above has them below a grid',
#   'A person seen from below has a grid above them'],
#  'head in the clouds': ['the clouds in head',
#   'the clouds head clouds',
#   'clouds in the head'],
#  'standing on feet': ['on feet standing'],
#  'They have sunglasses over their hair': ['They have their hair over sunglasses',
#   'They have their hair sunglasses hair',
#   'They have hair over their sunglasses'],
#  'an odd number of sweet things on a plate with an even number of sides': ['an odd number of sweet things on sides with an even number of sides a plate',
#   'an odd number of even things on a plate with an sweet number of sides',
#   'an odd number of sweet things on an even number a plate number of sides',
#   'sweet things of an odd number on a plate with an even number of sides',
#   'an sweet number of odd things on a plate with an even number of sides',
#   'a plate of sweet things on an odd number with an even number of sides',
#   'an odd number of sides on a plate with an even number of sides sweet things',
#   'an odd number of sweet things on a plate with sides of sides an even number',
#   'an sweet number of even things on a plate with an odd number of sides',
#   'sides of sweet things on a plate with an even number of sides an odd number',
#   'an odd number of sweet things on a plate with sides of an even number',
#   'a plate of sweet things on a an odd number an even number of sides',
#   'an odd number of a plate on sweet things with an even number of sides',
#   'sweet things of sweet an odd number a plate with an even number of sides',
#   'an odd number of an even number on a plate sweet things number of sides',
#   'an even number of odd things on a plate with an sweet number of sides',
#   'an even number of sweet things on a plate with an odd number of sides'],
#  'a large living thing in front of a large non-living thing': ['a living living thing in front of a non large - large thing',
#   'a living living thing in front of a large large non - thing',
#   'a non living thing in front of a - large large living thing',
#   'a - living thing in front of a large large living non thing',
#   'a large living thing in front of a non large - living thing',
#   'a large living thing in front of a large non living - thing',
#   'a large living thing in front of a - large non living thing',
#   'a large living thing in front of a living non - large thing',
#   'a large living thing in a large non - living thing of front',
#   'a - living thing in front of a non large living large thing',
#   'a large living thing in front of a living large non - thing',
#   'front in a large living thing of a large non - living thing',
#   'a non living thing in front of a large - large living thing',
#   'a living living thing in front of a large - large non thing',
#   'a living living thing in front of a large - non large thing',
#   'a living living thing in front of a - large large non thing',
#   'a living living thing in front of a - large non large thing',
#   'a large non - living thing in a large living thing living thing',
#   'a large living thing in front of a - non large living thing',
#   'a large living thing in front of a - large non living thing',
#   'a large living thing in front of a non living large - thing',
#   'a - living thing in front of a large living non large thing',
#   'a - living thing in front of a large non living large thing',
#   'a living living thing in front of a large non - large thing',
#   'a non living thing in front of a large living - large thing',
#   'a living living thing in front of a large - non large thing',
#   'a - living thing in front of a living large non large thing',
#   'a large living thing in front of a non - large living thing',
#   'a non living thing in front of a large large living - thing',
#   'a large living thing in front of a non - living large thing',
#   'a - living thing in front of a large large non living thing',
#   'a - living thing in front of a non large large living thing',
#   'a - living thing in front of a living large large non thing',
#   'a non living thing in front of a living large - large thing',
#   'a living living thing in front of a non large - large thing',
#   'a non living thing in front of a large living large - thing',
#   'a living living thing in front of a - large non large thing',
#   'a - living thing in front of a large living non large thing',
#   'a large living thing in front of a non - large living thing',
#   'a large living thing in front of a large living - non thing',
#   'a large living thing in front of a - living non large thing',
#   'a large living thing in front of a living - large non thing',
#   'a large living thing in front of a large living - non thing',
#   'a large living thing in front of a large - living non thing',
#   'a - living thing in front of a large non living large thing',
#   'a large living thing in front of a large - non living thing',
#   'a non living thing in front of a living large large - thing',
#   'a - living thing in front of a living large non large thing',
#   'a - living thing in front of a large large non living thing',
#   'a - living thing in front of a large living large non thing',
#   'a large living thing in front of a large - living non thing',
#   'a non living thing in front of a - large large living thing',
#   'a non living thing in front of a living large large - thing',
#   'a non living thing in front of a large large - living thing',
#   'a living living thing in front of a large large non - thing',
#   'a living living thing in front of a large large - non thing',
#   'a - living thing in front of a large non large living thing',
#   'a large living thing in front of a non - living large thing',
#   'a large living thing in front of a - large living non thing',
#   'a large living thing in front of a non living - large thing',
#   'a non living thing in front of a - large living large thing',
#   'a living living thing in front of a large non large - thing',
#   'a living living thing in front of a large non large - thing',
#   'a large living thing in front of a large non living - thing',
#   'a living living thing in front of a - non large large thing',
#   'a - living thing in front of a large large living non thing',
#   'a large living thing in front of a living non large - thing',
#   'a living living thing in front of a large large - non thing',
#   'a large living thing in front of a non large living - thing',
#   'a non living thing in front of a living - large large thing',
#   'a living living thing in front of a non large large - thing',
#   'a large living thing in front of a living large - non thing',
#   'a living living thing in front of a large - large non thing',
#   'a large living thing in a large front large non - living thing',
#   'a large living thing in front of a living - large non thing',
#   'front in front of a a large living thing non - living thing',
#   'a large living thing in front of a - non living large thing',
#   'a non living thing in front of a large living - large thing',
#   'a large living thing in front of a non large living - thing',
#   'a non living thing in front of a - living large large thing',
#   'a non living thing in front of a large - living large thing',
#   'a large living thing in front of a living - non large thing',
#   'a non living thing in front of a living - large large thing',
#   'a - living thing in front of a non living large large thing',
#   'a living living thing in front of a - large large non thing',
#   'a living living thing in front of a - non large large thing',
#   'a large living thing in front of a living non - large thing',
#   'a large living thing in front of a - living large non thing',
#   'a non living thing in front of a - living large large thing',
#   'a non living thing in front of a - large living large thing',
#   'a living living thing in front of a non large large - thing',
#   'a large living thing in front of a - living large non thing',
#   'a large living thing in front of a large - non living thing',
#   'a non living thing in front of a large living large - thing',
#   'a non living thing in front of a living large - large thing',
#   'a - living thing in front of a living non large large thing',
#   'a living living thing in front of a large non - large thing',
#   'a living living thing in front of a non - large large thing',
#   'a large living thing in front of a - non living large thing',
#   'a living living thing in front of a non - large large thing',
#   'a large living thing in front of a - living non large thing',
#   'a large living thing in front of a - large living non thing',
#   'a large living thing in front of a living large non - thing',
#   'a non living thing in front of a large large living - thing',
#   'a large living thing in front of a - non large living thing',
#   'a - living thing in front of a non living large large thing',
#   'a non living thing in front of a large large - living thing',
#   'a large living thing in front of a non living large - thing',
#   'a large living thing in front of a living - non large thing',
#   'a large living thing in front of a large living non - thing',
#   'a - living thing in front of a large non large living thing',
#   'a - living thing in front of a non large large living thing',
#   'a large living thing in front of a large living non - thing',
#   'a non living thing in front of a large - living large thing',
#   'a non living thing in front of a large - large living thing',
#   'a large living thing in front of a non living - large thing',
#   'a - living thing in front of a large living large non thing',
#   'a - living thing in front of a non large living large thing',
#   'a large living thing in front of a non large - living thing',
#   'a - living thing in front of a living non large large thing',
#   'a large living thing in front of a living non large - thing',
#   'a large living thing in front of a living large - non thing',
#   'a - living thing in front of a living large large non thing',
#   'a large non - living thing in front of a large living thing'],
#  'racing over it': ['racing it over'],
#  'someone is overdoing it': ['someone is doing it over']}

# %%
# filter by minilm similarity
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('sentence-transformers/paraphrase-MiniLM-L12-v2')
embeddings = model.encode(sentences)
# compute cosine similarity
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity([embeddings[0]], [embeddings[1]])
# Out:
# array([[0.36930478]], dtype=float32)

# %%
for caption, swaps in tqdm(augmented_caption.items()):
    new_swap = [swap for swap in swaps if cosine_similarity([model.encode(caption)], [model.encode(swap)]) > 0.7]
    augmented_caption[caption] = new_swap

# %%
augmented_caption
# Out:
# {'an old person kisses a young person': ['an young person kisses a old person',
#   'a young person kisses an old person'],
#  'the taller person hugs the shorter person': ['the shorter person hugs the taller person'],
#  'the masked wrestler hits the unmasked wrestler': ['the unmasked wrestler hits the masked wrestler'],
#  'a person watches an animal': ['an animal watches a person'],
#  'the person without earrings pays the person with earrings': ['earrings without earrings pays the person with earrings the person',
#   'the person without earrings pays earrings with earrings the person',
#   'earrings without the person pays the person with earrings',
#   'earrings without earrings pays the person with the person',
#   'earrings without earrings the person the person with earrings',
#   'the person without the person earrings person with earrings',
#   'the person with earrings pays the person without earrings'],
#  'a bird eats a snake': ['a snake eats a bird'],
#  'a plant was harmed by another organism, and that organism broke the plant into pieces': ['a plant was harmed by the plant , and that organism broke another organism into pieces',
#   'pieces was harmed by another organism , and that organism broke the plant into pieces a plant',
#   'organism was harmed by another organism , and that organism a plant the plant into pieces',
#   'a plant was harmed by another organism , and that the plant organism plant into pieces',
#   'the plant was harmed by another organism , and that organism broke a plant into pieces',
#   'a plant was harmed by organism , and that organism another organism the plant into pieces',
#   'a plant was harmed by another organism , and that pieces broke the plant into organism',
#   'a plant was harmed by pieces , and that organism broke the plant into pieces another organism',
#   'another organism was harmed by a plant , and that organism broke the plant into pieces',
#   'a plant was harmed by another organism , and that organism broke pieces into pieces the plant',
#   'another organism was harmed by a plant , and that plant broke the organism into pieces'],
#  'a bottle is in water': ['water is in water a bottle',
#   'water is in a bottle'],
#  'a tree smashed into a car': ['a car smashed into a tree'],
#  'people fall on the leaves': ['the leaves fall people leaves',
#   'the leaves fall on people'],
#  'the sail rests below the water': ['the water rests below the sail'],
#  'there is a table below someone': ['there is someone below a table'],
#  'the image shows a computer on top of books': ['books shows a computer on top of books the image',
#   'top shows a computer on the image of books',
#   'the image shows top on top a computer books',
#   'top shows a computer on top the image books',
#   'the image shows a computer on books of top',
#   'the image shows books on top of books a computer',
#   'a computer shows the image on top of books',
#   'the image shows books on top of a computer'],
#  'a caterpillar with some plants': ['some plants with a caterpillar',
#   'a plant with some caterpillars'],
#  'there is a mug in some grass': ['there is some grass in a mug'],
#  'there are more skiers than snowboarders': ['there are snowboarders than snowboarders more skiers',
#   'there are snowboarders than more skiers',
#   'there are more snowboarders than skiers'],
#  'there are fewer forks than spoons': ['there are spoons than fewer forks',
#   'there are spoons than spoons fewer forks',
#   'there are fewer spoons than forks'],
#  'there are more ladybugs than flowers': ['there are flowers than flowers more ladybugs',
#   'there are flowers than more ladybugs',
#   'there are more flowers than ladybugs'],
#  'there is less orange juice than milk': ['there is orange less juice than milk',
#   'there is milk than milk less orange juice',
#   'there is milk than less orange juice',
#   'there is less milk than orange juice'],
#  'there is more dirt than empty space in the jar': ['there is empty space than more dirt in the jar',
#   'there is more dirt than the jar in empty space',
#   'there is the jar than empty space in more dirt',
#   'there is empty dirt than more space in the jar',
#   'there is more empty space than dirt in the jar'],
#  'there is a bit less milk chocolate than white chocolate': ['there is white chocolate than white chocolate a bit less milk chocolate',
#   'there is white chocolate than a bit less milk chocolate',
#   'there is a bit white milk chocolate than less chocolate',
#   'there is a bit less white chocolate than milk chocolate'],
#  'a person sits and a dog stands': ['a dog sits and a person stands',
#   'a person stands and a dog sits'],
#  'The person with more facial hair lies awake while the other sleeps': ['The person with more other hair lies awake while the facial sleeps',
#   'more facial hair with The person lies awake while the other sleeps',
#   'The person with more awake hair lies facial while the other sleeps',
#   'more facial hair The person hair lies awake while the other sleeps',
#   'The person with more other hair lies facial while the awake sleeps',
#   'The person with more facial hair lies other while the awake sleeps',
#   'The person with more awake hair lies other while the facial sleeps',
#   'The person with more facial hair sleeps while the other lies awake'],
#  'the person in the middle is floating and some others are standing': ['some others in the middle is floating and the person are standing',
#   'the middle in the person is floating and some others are standing',
#   'the person in some others is floating and the middle are standing',
#   'the person in the middle is standing and some others are floating'],
#  'the person closer to the camera weightlifts and the person farther from the camera runs': ['weightlifts closer to the camera weightlifts the person the person farther from the camera runs',
#   'the person closer to weightlifts weightlifts the camera the person farther from the camera runs',
#   'the person closer to the person weightlifts and the camera farther from the camera runs',
#   'the person closer to the camera the person weightlifts person farther from the camera runs',
#   'the camera closer to the person weightlifts and the person farther from the camera runs',
#   'the person closer to the camera runs and the person farther from the camera weightlifts'],
#  'the person with the white collared shirt waters the plant while the other holds it': ['the person with the collared other shirt waters the plant while the white holds it',
#   'the plant with the white collared shirt waters the person while the other holds it',
#   'the person with the other white shirt waters the plant while the collared holds it',
#   'the person with the collared white shirt waters the plant while the other holds it',
#   'the white collared the person collared shirt waters the plant while the other holds it',
#   'the white collared shirt with the person waters the plant while the other holds it',
#   'the person with the plant waters the plant the white collared shirt other holds it',
#   'the person with the other collared shirt waters the plant while the white holds it',
#   'the person with the white other shirt waters the plant while the collared holds it',
#   'the person with the white collared shirt holds the plant while the other waters it'],
#  'the taller person chops food and the shorter person eats food': ['the shorter person chops food and the taller person eats food',
#   'the taller person chops the shorter food shorter person eats food',
#   'the taller person chops food and food eats food the shorter person',
#   'the shorter person chops food and the taller person eats food',
#   'food chops food and the shorter person eats food the taller person',
#   'food chops food and the taller person shorter person eats food',
#   'the taller person eats food and the shorter person chops food'],
#  'the person with the ponytail packs stuff and other buys it': ['the ponytail packs stuff with the person and other buys it',
#   'the ponytail packs the person packs stuff and other buys it',
#   'the person with the ponytail buys stuff and other packs it'],
#  'a person walking in a field of yellow flowers with a red dress': ['a person walking in yellow flowers of a field with a red dress',
#   'a person walking in a red dress of yellow flowers a field dress',
#   'a field walking in a person of yellow flowers with a red dress',
#   'yellow flowers walking in a field of a person with a red dress',
#   'a red dress walking in a field of yellow flowers a person dress',
#   'a person walking in a field of a red dress yellow flowers dress',
#   'a person walking in a field of red flowers with a yellow dress'],
#  'a brown dog is on a white couch': ['a white couch is on a brown dog',
#   'a white dog is on a brown couch'],
#  'a blue bird is next to a red berry': ['a red bird is blue to a next berry',
#   'a blue bird is red to a next berry',
#   'a red berry is next to a blue bird',
#   'a next bird is blue to a red berry',
#   'a next bird is red to a blue berry',
#   'a red bird is next to a blue berry'],
#  'The red book is above the yellow book and below the blue book': ['The red book is above the blue book and below the yellow book',
#   'the yellow book is above The red book and below the blue book',
#   'The yellow book is above the red book and below the blue book',
#   'The red book is above the blue book and below the yellow book',
#   'The blue book is above the red book and below the yellow book',
#   'the blue book is above the yellow book and below The red book',
#   'The blue book is above the yellow book and below the red book',
#   'The yellow book is above the blue book and below the red book'],
#  'astronauts in blue suits with a red planet in the background': ['blue suits in astronauts with a red planet in the background',
#   'the background in blue suits with a red planet astronauts background',
#   'astronauts in blue suits with the background in the a red planet',
#   'astronauts in a red planet blue suits planet in the background',
#   'a red planet in blue astronauts red planet in the background',
#   'a red planet in blue suits with astronauts in the background',
#   'astronauts in blue suits with the background in a red planet',
#   'astronauts in the background with a red planet in blue suits',
#   'blue suits astronauts suits with a red planet in the background',
#   'astronauts in red suits with a blue planet in the background'],
#  'the square table has a round base': ['a round base has the square table',
#   'the round table has a square base'],
#  'pointy bushes are behind rectangular bushes': ['rectangular bushes are behind pointy bushes'],
#  'a circular sign is above a rectangular sign': ['a rectangular sign is above a circular sign'],
#  'a wood chess piece rests on metal objects': ['metal objects rests on metal objects a wood chess piece',
#   'metal objects rests on a wood chess piece',
#   'a metal chess piece rests on wood objects'],
#  'soft shoes are on a smooth floor': ['a smooth floor are soft shoes floor',
#   'smooth shoes are on a soft floor'],
#  'the happy person is on the right and the sad person is on the left': ['the left person is on the right and the sad person is on the happy',
#   'the happy person is on the right and the left person is on the sad',
#   'the right is on the the happy person the sad person is on the left',
#   'the left person is on the right and the happy person is on the sad',
#   'the sad person is on the right and the left person is on the happy',
#   'the happy person is on the sad person the right person is on the left',
#   'the sad person is on the right and the happy person is on the left'],
#  'the hurt person is on the left and the helpful person is on the right': ['the hurt person is on the right and the helpful person is on the left',
#   'the left is on the the hurt person the helpful person is on the right',
#   'the right is on the left and the helpful person is on the the hurt person',
#   'the hurt person is on the left and the right is on the the helpful person',
#   'the hurt person is on the helpful person the left person is on the right',
#   'the helpful person is on the left and the hurt person is on the right'],
#  'the more content person has the healthier food and the less content person has the less healthy food': ['the more content person has the healthier food and the less healthy food has the less content person',
#   'the more content person has the healthy food and the less content person has the less healthier food',
#   'the more content person has the less content person the healthier food person has the less healthy food',
#   'the less healthy food has the healthier food and the less content person has the more content person',
#   'the healthier food has the the more content person the less content person has the less healthy food',
#   'the more content person has the less healthy food and the less content person the healthier food food',
#   'the less content person has the healthier food and the more content person has the less healthy food'],
#  'the orange lollipop is sad and the red lollipop is surprised': ['the orange lollipop is red and the surprised lollipop is sad',
#   'the red lollipop is sad and the surprised lollipop is orange',
#   'the orange lollipop is red and the sad lollipop is surprised',
#   'the surprised lollipop is red and the sad lollipop is orange',
#   'the sad lollipop is red and the surprised lollipop is orange',
#   'the red lollipop is surprised and the orange lollipop is sad',
#   'the orange lollipop is sad and the surprised lollipop is red',
#   'the red lollipop is orange and the surprised lollipop is sad',
#   'the sad lollipop is orange and the red lollipop is surprised',
#   'the sad lollipop is surprised and the orange lollipop is red',
#   'the red lollipop is sad and the orange lollipop is surprised',
#   'the red lollipop is sad and the orange lollipop is surprised',
#   'the surprised lollipop is red and the orange lollipop is sad',
#   'the sad lollipop is red and the orange lollipop is surprised',
#   'the surprised lollipop is orange and the red lollipop is sad',
#   'the sad lollipop is orange and the surprised lollipop is red',
#   'the surprised lollipop is orange and the sad lollipop is red',
#   'the red lollipop is orange and the sad lollipop is surprised',
#   'the sad lollipop is surprised and the red lollipop is orange',
#   'the surprised lollipop is sad and the red lollipop is orange',
#   'the orange lollipop is surprised and the sad lollipop is red',
#   'the surprised lollipop is sad and the orange lollipop is red',
#   'the red lollipop is surprised and the sad lollipop is orange',
#   'the orange lollipop is surprised and the red lollipop is sad'],
#  'the larger person wears yellow and the smaller person does not': ['the yellow person wears larger and the smaller person does not',
#   'the smaller person wears larger and the yellow person does not',
#   'the larger person wears smaller and the yellow person does not',
#   'the yellow person wears smaller and the larger person does not',
#   'the smaller person wears yellow and the larger person does not'],
#  'a big cat is next to a small dog': ['a next cat is big to a small dog',
#   'a small dog is next to a big cat',
#   'a big cat is small to a next dog',
#   'a small cat is big to a next dog',
#   'a next cat is small to a big dog',
#   'a small cat is next to a big dog'],
#  'the heavy oncoming traffic is contrasted with the light outgoing traffic': ['the light oncoming traffic is contrasted with the outgoing heavy traffic',
#   'the light heavy traffic is contrasted with the outgoing oncoming traffic',
#   'the oncoming light traffic is contrasted with the heavy outgoing traffic',
#   'the outgoing light traffic is contrasted with the oncoming heavy traffic',
#   'the oncoming outgoing traffic is contrasted with the light heavy traffic',
#   'the heavy outgoing traffic is contrasted with the oncoming light traffic',
#   'the outgoing light traffic is contrasted with the heavy oncoming traffic',
#   'the light outgoing traffic is contrasted with the oncoming heavy traffic',
#   'the oncoming heavy traffic is contrasted with the light outgoing traffic',
#   'the heavy oncoming traffic is contrasted with the outgoing light traffic',
#   'the light outgoing traffic is contrasted with the heavy oncoming traffic',
#   'the light outgoing traffic is contrasted with the heavy oncoming traffic',
#   'the heavy outgoing traffic is contrasted with the light oncoming traffic',
#   'the outgoing heavy traffic is contrasted with the oncoming light traffic',
#   'the oncoming heavy traffic is contrasted with the outgoing light traffic',
#   'the heavy light traffic is contrasted with the outgoing oncoming traffic',
#   'the outgoing oncoming traffic is contrasted with the heavy light traffic',
#   'the light heavy traffic is contrasted with the oncoming outgoing traffic',
#   'the heavy light traffic is contrasted with the oncoming outgoing traffic',
#   'the oncoming light traffic is contrasted with the outgoing heavy traffic',
#   'the outgoing oncoming traffic is contrasted with the light heavy traffic',
#   'the oncoming outgoing traffic is contrasted with the heavy light traffic',
#   'the outgoing heavy traffic is contrasted with the light oncoming traffic',
#   'the light oncoming traffic is contrasted with the heavy outgoing traffic'],
#  'a cold drink on a hot day': ['a hot day on a cold drink',
#   'a hot drink on a cold day'],
#  'a person is drinking now and eating later': ['a person is drinking later and eating now'],
#  'the sailboat sails close but the beach is far away': ['the beach sails close but the sailboat is far away',
#   'the sailboat sails far away but the beach is close'],
#  'the passenger is riding inattentive to the road and the driver is driving attentive to the road': ['the passenger is riding inattentive to the road and the road is driving attentive to the driver',
#   'the driver is riding inattentive to the road and the passenger is driving attentive to the road',
#   'the road is riding inattentive to the passenger and the driver is driving attentive to the road',
#   'the passenger is riding inattentive to the driver and the road is driving attentive to the road',
#   'the road is riding inattentive to the road and the driver is driving attentive to the passenger',
#   'the passenger is riding attentive to the road and the driver is driving inattentive to the road'],
#  "it wears a hat but the person doesn't": ["it wears the person but a hat does n't",
#   "the person wears a hat but it does n't"],
#  'the person with green legs is running quite slowly and the red legged one runs faster': ['green legs with the person is running quite slowly and the red legged one runs faster',
#   'the person with green legs is running quite slowly and the legged red one runs faster',
#   'the person with legged legs is running quite slowly and the green red one runs faster',
#   'the person with legged legs is running quite slowly and the red green one runs faster',
#   'the person with red legs is running quite slowly and the green legged one runs faster',
#   'the person with red legs is running quite slowly and the legged green one runs faster',
#   'the person with green legs is running faster and the red legged one runs quite slowly'],
#  'a person is in the water and close to the sand': ['a person is in the sand and close to the water',
#   'the water is in a person and close to the sand',
#   'the sand is in the water and close to a person',
#   'a person is close to the water and in the sand'],
#  'a frog is above rocks which are under the water': ['a frog is above the water which are rocks water',
#   'the water is above rocks which are under a frog',
#   'rocks is above rocks a frog are under the water',
#   'a frog is under rocks which are above the water'],
#  'driving off the road and on the unpaved terrain': ['driving off the unpaved terrain and the road terrain',
#   'driving on the road and off the unpaved terrain'],
#  'someone is in a helicopter with a car': ['someone is in a car with a helicopter',
#   'someone is with a helicopter in a car'],
#  'the green one can fit inside the blue one and the blue one can fit outside the green one': ['the green one can fit inside the green one and the blue one can fit outside the blue one',
#   'the blue one can fit inside the green one and the blue one can fit outside the green one',
#   'the blue one can fit inside the blue one and the green one can fit outside the green one',
#   'the blue one can fit inside the green one and the green one can fit outside the blue one',
#   'the blue one can fit inside the blue one and the green one can fit outside the green one',
#   'the blue one can fit inside the blue one and the green one can fit outside the green one',
#   'the green one can fit inside the green one and the blue one can fit outside the blue one',
#   'the blue one can fit inside the green one and the green one can fit outside the blue one',
#   'the blue one can fit inside the blue one and the green one can fit outside the green one',
#   'the blue one can fit inside the green one and the blue one can fit outside the green one',
#   'the green one can fit inside the blue one and the green one can fit outside the blue one',
#   'the green one can fit inside the green one and the blue one can fit outside the blue one',
#   'the green one can fit inside the blue one and the green one can fit outside the blue one',
#   'the green one can fit inside the green one and the blue one can fit outside the blue one',
#   'the blue one can fit inside the green one and the blue one can fit outside the green one',
#   'the blue one can fit inside the green one and the green one can fit outside the blue one',
#   'the blue one can fit inside the green one and the blue one can fit outside the green one',
#   'the green one can fit inside the blue one and the green one can fit outside the blue one',
#   'the blue one can fit inside the green one and the blue one can fit outside the green one',
#   'the green one can fit inside the blue one and the green one can fit outside the blue one',
#   'the green one can fit inside the blue one and the green one can fit outside the blue one',
#   'the green one can fit inside the green one and the blue one can fit outside the blue one',
#   'the blue one can fit inside the blue one and the green one can fit outside the green one',
#   'the blue one can fit inside the green one and the green one can fit outside the blue one',
#   'the green one can fit outside the blue one and the blue one can fit inside the green one'],
#  'jumping away from the photographer and towards the others': ['jumping away from the others and towards the photographer',
#   'jumping towards the photographer and away from the others'],
#  'someone bakes the dough before the dough is eaten': ['the dough is eaten before someone bakes the dough'],
#  'it hatched before it was eaten': ['it was eaten before it hatched'],
#  'there are three bananas and two apples': ['there are two apples and three bananas',
#   'there are two bananas and three apples'],
#  'someone has loaded their plate with one of the toast slices and two of the eggs': ['someone has loaded the eggs with one of the toast slices and two of their plate',
#   'someone has loaded their plate with one of the eggs and two of the the toast slices',
#   'someone has loaded the toast slices with one their plate slices and two of the eggs',
#   'someone has loaded their plate with two of the toast slices and one of the eggs'],
#  'there are three people and two windows': ['there are two windows and three people',
#   'there are two people and three windows'],
#  'there are 50 stars on the right flag and 5 stars on the left flag': ['there are 50 stars on the right flag and the left flag on 5 stars',
#   'there are 50 stars on 5 stars and 5 the right flag the left flag',
#   'there are 50 stars on the left flag and 5 stars on the right flag',
#   'there are the left flag on the right flag and 5 stars 50 stars flag',
#   'there are the right flag 50 stars flag and 5 stars on the left flag',
#   'there are 50 stars on the left flag and 5 stars on the right flag',
#   'there are the right flag on 50 stars and 5 stars on the left flag',
#   'there are 50 stars on the right flag and the left flag 5 stars flag',
#   'there are 5 stars on the right flag and 50 stars on the left flag'],
#  'no people wear blue shirts and six people wear white shirts': ['no people wear white shirts and six people wear blue shirts',
#   'blue shirts wear no people and six people wear white shirts',
#   'no people wear white shirts and six people wear blue shirts',
#   'white shirts wear blue shirts and six people wear no people',
#   'no people wear six people and blue shirts wear white shirts',
#   'no people wear blue shirts and white shirts wear six people',
#   'six people wear blue shirts and no people wear white shirts'],
#  "the dog's leg is on the person's torso": ["the person 's torso is on the dog 's leg",
#   "the person 's leg is on the dog 's torso"],
#  "the animal's eyes are bigger than the person's": ["the person are bigger than the person the animal 's eyes",
#   "the person 's eyes are bigger than the animal 's"],
#  "the taller person's arm is around the shorter person's shoulder": ["the shorter person 's shoulder is around the taller person 's arm",
#   "the shorter person 's arm is around the taller person 's shoulder"],
#  'the person in a brown coat looks back and the person in a black coat looks forward': ['a black coat in a brown coat looks back and the person the person coat looks forward',
#   'a brown coat in the person looks back and the person in a black coat looks forward',
#   'the person in a brown coat looks back and a black coat in the person looks forward',
#   'the person in a brown coat looks back and a black coat the person coat looks forward',
#   'a brown coat the person coat looks back and the person in a black coat looks forward',
#   'the person in the person looks back and the a brown coat a black coat looks forward',
#   'the person in a black coat looks back and the person in a brown coat looks forward'],
#  'it ran away while they pursued': ['they ran away while it pursued'],
#  'almost everyone is in a boat and one is swimming': ['almost everyone is in one and one a boat swimming',
#   'one is in a boat and almost everyone is swimming'],
#  "the person with the lighter shoes is holding an emoji and the person with the darker shoes isn't": ["the person with the lighter shoes is holding the person and an emoji with the darker shoes is n't",
#   "the person with the lighter shoes is holding an emoji and the darker shoes with the person is n't",
#   "an emoji with the lighter shoes is holding the person and the person with the darker shoes is n't",
#   "the person with the lighter shoes is holding an emoji and the darker shoes the person shoes is n't",
#   "the person with an emoji is holding an the lighter shoes the person with the darker shoes is n't",
#   "the lighter shoes the person shoes is holding an emoji and the person with the darker shoes is n't",
#   "the darker shoes with the lighter shoes is holding an emoji and the person the person shoes is n't",
#   "the lighter shoes with the person is holding an emoji and the person with the darker shoes is n't",
#   "the person with the person is holding an emoji and the the lighter shoes the darker shoes is n't",
#   "the person with the lighter shoes is holding the darker shoes and the person an emoji shoes is n't",
#   "the person with the darker shoes is holding an emoji and the person with the lighter shoes is n't"],
#  'the person wearing neutral colors poses and the person wearing brighter colors takes a picture': ['neutral colors poses the person poses and the person wearing brighter colors takes a picture',
#   'a picture wearing neutral colors poses and the person wearing brighter colors takes the person',
#   'the person wearing neutral colors poses and brighter colors wearing the person takes a picture',
#   'the person wearing the person and the neutral colors poses brighter colors takes a picture',
#   'brighter colors wearing neutral colors poses and the person wearing the person takes a picture',
#   'the person wearing a picture and the person wearing brighter colors takes a neutral colors poses',
#   'the person wearing neutral colors poses and the person wearing a picture takes brighter colors',
#   'the person wearing brighter colors and the person wearing brighter neutral colors poses a picture',
#   'the person wearing neutral colors poses and a picture wearing brighter colors takes the person',
#   'the person wearing brighter colors poses and the person wearing neutral colors takes a picture'],
#  "it's a fire truck": ["it 's a truck fire"],
#  'watching the present': [],
#  'walking out on a rock': [],
#  'the kid with the magnifying glass looks at them': ['them with the magnifying glass looks at the kid',
#   'the magnifying glass the kid glass looks at them',
#   'the magnifying glass with the kid looks at them',
#   'the kid looks at them with the magnifying glass'],
#  'the person with the kids is sitting': ['the kids with the person is sitting',
#   'the person is sitting with the kids'],
#  'the people with shoes are touching each other': ['shoes with the people are touching each other',
#   'shoes with shoes the people touching each other',
#   'the people are touching each other with shoes'],
#  'someone with an apple is hurt by a tree': ['someone with a tree is hurt by an apple',
#   'someone is hurt by a tree with an apple'],
#  'the person that is on the table is eating the food': ['the person that is on the food is eating the table',
#   'the table that is on the person is eating the food',
#   'the food that is on the table is eating the person',
#   'the person is eating the food that is on the table'],
#  'the watering can is larger than the pot': ['the pot can is larger than the watering',
#   'the pot is larger than the watering can'],
#  'they hold a suitcase handle with their left hand and they hold a passport with their right hand': ['they hold a suitcase handle with their right hand and they hold a passport with their left hand',
#   'they hold a suitcase handle with a passport and they hold a their left hand their right hand',
#   'they hold a passport with their left hand and they hold a a suitcase handle their right hand',
#   'they hold a suitcase handle with their left hand and their right hand hold a passport with they',
#   'they hold a suitcase handle with their left hand and they hold their right hand a passport hand',
#   'they hold their left hand with a suitcase handle and they hold a passport with their right hand',
#   'they hold their right hand with their left hand and they hold a passport with a suitcase handle',
#   'they hold a suitcase handle with their right hand and they hold a passport with their left hand',
#   'they hold a passport with their left hand and they hold a suitcase handle with their right hand'],
#  'the person with the patterned shirt is curly-haired and the other is straight-haired': ['the person with the haired shirt is patterned - straight and the haired is curly - other',
#   'the person with the other shirt is curly - patterned and the haired is straight - haired',
#   'the person with the straight shirt is patterned - curly and the haired is other - haired',
#   'the person with the curly shirt is haired - straight and the patterned is haired - other',
#   'the person with the curly shirt is haired - haired and the straight is other - patterned',
#   'the person with the haired shirt is curly - patterned and the haired is other - straight',
#   'the person with the patterned shirt is haired - other and the haired is curly - straight',
#   'the person with the straight shirt is haired - curly and the other is haired - patterned',
#   'the person with the haired shirt is haired - curly and the straight is other - patterned',
#   'the person with the straight shirt is haired - patterned and the haired is curly - other',
#   'the person with the straight shirt is haired - other and the patterned is haired - curly',
#   'the person with the haired shirt is straight - patterned and the haired is curly - other',
#   'the person with the straight shirt is patterned - haired and the curly is haired - other',
#   'the person with the straight shirt is haired - patterned and the curly is other - haired',
#   'the person with the patterned shirt is curly - other and the haired is haired - straight',
#   'the person with the haired shirt is haired - patterned and the straight is other - curly',
#   'the person with the haired shirt is straight - patterned and the curly is other - haired',
#   'the person with the haired shirt is other - haired and the curly is patterned - straight',
#   'the person with the curly shirt is haired - patterned and the other is haired - straight',
#   'the person with the patterned shirt is curly - straight and the other is haired - haired',
#   'the person with the straight shirt is curly - other and the haired is patterned - haired',
#   'the person with the other shirt is haired - patterned and the curly is straight - haired',
#   'the person with the patterned shirt is straight - haired and the curly is haired - other',
#   'the person with the haired shirt is patterned - curly and the haired is straight - other',
#   'the person with the haired shirt is haired - straight and the other is patterned - curly',
#   'the person with the patterned shirt is other - haired and the curly is straight - haired',
#   'the person with the curly shirt is other - straight and the haired is haired - patterned',
#   'the person with the curly shirt is patterned - haired and the straight is haired - other',
#   'the person with the patterned shirt is haired - curly and the other is haired - straight',
#   'the person with the patterned shirt is haired - other and the haired is curly - straight',
#   'the person with the curly shirt is haired - other and the straight is haired - patterned',
#   'the person with the haired shirt is straight - curly and the patterned is other - haired',
#   'the person with the haired shirt is other - patterned and the straight is haired - curly',
#   'the person with the curly shirt is other - haired and the haired is straight - patterned',
#   'the person with the curly shirt is straight - haired and the haired is other - patterned',
#   'the person with the haired shirt is patterned - straight and the haired is other - curly',
#   'the person with the patterned shirt is haired - other and the haired is straight - curly',
#   'the person with the other shirt is patterned - haired and the straight is curly - haired',
#   'the person with the haired shirt is patterned - haired and the straight is curly - other',
#   'the person with the other shirt is haired - curly and the straight is haired - patterned',
#   'the person with the patterned shirt is straight - curly and the haired is other - haired',
#   'the person with the patterned shirt is haired - curly and the straight is other - haired',
#   'the person with the haired shirt is haired - patterned and the other is straight - curly',
#   'the person with the other shirt is curly - patterned and the haired is straight - haired',
#   'the person with the haired shirt is straight - curly and the haired is patterned - other',
#   'the person with the haired shirt is patterned - curly and the other is straight - haired',
#   'the person with the straight shirt is haired - haired and the patterned is curly - other',
#   'the person with the other shirt is straight - curly and the patterned is haired - haired',
#   'the person with the other shirt is haired - straight and the curly is patterned - haired',
#   'the person with the straight shirt is haired - curly and the other is haired - patterned',
#   'the person with the straight shirt is other - haired and the patterned is curly - haired',
#   'the person with the curly shirt is patterned - other and the haired is haired - straight',
#   'the person with the curly shirt is patterned - straight and the haired is other - haired',
#   'the person with the other shirt is haired - patterned and the curly is haired - straight',
#   'the person with the haired shirt is patterned - other and the straight is curly - haired',
#   'the person with the haired shirt is haired - patterned and the other is curly - straight',
#   'the person with the patterned shirt is haired - other and the haired is straight - curly',
#   'the person with the other shirt is haired - curly and the haired is patterned - straight',
#   'the person with the straight shirt is patterned - haired and the other is curly - haired',
#   'the person with the haired shirt is patterned - haired and the straight is other - curly',
#   'the person with the curly shirt is straight - haired and the patterned is haired - other',
#   'the person with the patterned shirt is haired - haired and the curly is other - straight',
#   'the person with the haired shirt is other - haired and the patterned is curly - straight',
#   'the person with the haired shirt is curly - other and the patterned is haired - straight',
#   'the person with the patterned shirt is other - curly and the haired is straight - haired',
#   'the person with the curly shirt is haired - other and the haired is patterned - straight',
#   'the person with the haired shirt is other - patterned and the haired is straight - curly',
#   'the person with the patterned shirt is other - straight and the haired is curly - haired',
#   'the person with the curly shirt is other - patterned and the straight is haired - haired',
#   'the person with the straight shirt is other - haired and the patterned is curly - haired',
#   'the person with the other shirt is haired - haired and the patterned is curly - straight',
#   'the person with the straight shirt is haired - patterned and the other is haired - curly',
#   'the person with the straight shirt is haired - haired and the patterned is other - curly',
#   'the person with the curly shirt is other - haired and the patterned is haired - straight',
#   'the person with the haired shirt is haired - curly and the straight is other - patterned',
#   'the person with the haired shirt is other - haired and the patterned is curly - straight',
#   'the person with the patterned shirt is curly - other and the straight is haired - haired',
#   'the person with the haired shirt is curly - other and the haired is straight - patterned',
#   'the person with the haired shirt is haired - other and the patterned is straight - curly',
#   'the person with the haired shirt is haired - other and the straight is curly - patterned',
#   'the person with the haired shirt is curly - straight and the haired is other - patterned',
#   'the person with the other shirt is haired - haired and the curly is patterned - straight',
#   'the person with the straight shirt is other - curly and the haired is patterned - haired',
#   'the person with the straight shirt is haired - curly and the haired is patterned - other',
#   'the person with the patterned shirt is straight - curly and the haired is haired - other',
#   'the person with the patterned shirt is curly - other and the haired is haired - straight',
#   'the person with the patterned shirt is other - haired and the haired is straight - curly',
#   'the person with the patterned shirt is straight - haired and the haired is curly - other',
#   'the person with the straight shirt is curly - patterned and the haired is haired - other',
#   'the person with the haired shirt is haired - curly and the other is straight - patterned',
#   'the person with the straight shirt is patterned - curly and the other is haired - haired',
#   'the person with the haired shirt is haired - other and the patterned is curly - straight',
#   'the person with the haired shirt is haired - patterned and the curly is straight - other',
#   'the person with the straight shirt is curly - haired and the patterned is haired - other',
#   'the person with the haired shirt is haired - curly and the patterned is other - straight',
#   'the person with the curly shirt is patterned - haired and the other is haired - straight',
#   'the person with the straight shirt is haired - patterned and the haired is other - curly',
#   'the person with the haired shirt is other - curly and the patterned is haired - straight',
#   'the person with the curly shirt is straight - other and the haired is patterned - haired',
#   'the person with the curly shirt is haired - straight and the haired is patterned - other',
#   'the person with the curly shirt is other - haired and the straight is haired - patterned',
#   'the person with the straight shirt is patterned - haired and the haired is curly - other',
#   'the person with the curly shirt is haired - straight and the haired is other - patterned',
#   'the person with the curly shirt is haired - straight and the haired is other - patterned',
#   'the person with the haired shirt is straight - other and the curly is patterned - haired',
#   'the person with the other shirt is curly - haired and the haired is patterned - straight',
#   'the person with the haired shirt is haired - other and the curly is straight - patterned',
#   'the person with the other shirt is straight - haired and the curly is haired - patterned',
#   'the person with the patterned shirt is haired - curly and the haired is other - straight',
#   'the person with the haired shirt is haired - straight and the curly is patterned - other',
#   'the person with the patterned shirt is haired - other and the curly is haired - straight',
#   'the person with the curly shirt is patterned - haired and the haired is straight - other',
#   'the person with the haired shirt is curly - straight and the haired is other - patterned',
#   'the person with the curly shirt is haired - haired and the other is patterned - straight',
#   'the person with the haired shirt is patterned - straight and the curly is other - haired',
#   'the person with the other shirt is haired - haired and the patterned is straight - curly',
#   'the person with the straight shirt is haired - haired and the curly is other - patterned',
#   'the person with the haired shirt is patterned - other and the curly is haired - straight',
#   'the person with the curly shirt is patterned - other and the haired is straight - haired',
#   'the person with the straight shirt is curly - other and the haired is haired - patterned',
#   'the person with the patterned shirt is curly - straight and the haired is haired - other',
#   'the person with the haired shirt is other - curly and the straight is haired - patterned',
#   'the person with the haired shirt is other - haired and the straight is curly - patterned',
#   'the person with the haired shirt is haired - straight and the patterned is curly - other',
#   'the person with the patterned shirt is straight - haired and the curly is other - haired',
#   'the person with the patterned shirt is curly - haired and the haired is other - straight',
#   'the person with the haired shirt is straight - other and the curly is patterned - haired',
#   'the person with the other shirt is straight - haired and the patterned is haired - curly',
#   'the person with the patterned shirt is other - straight and the haired is curly - haired',
#   'the person with the straight shirt is patterned - haired and the haired is curly - other',
#   'the person with the other shirt is patterned - straight and the haired is haired - curly',
#   'the person with the other shirt is straight - curly and the haired is patterned - haired',
#   'the person with the straight shirt is haired - haired and the curly is other - patterned',
#   'the person with the other shirt is haired - patterned and the straight is haired - curly',
#   'the person with the haired shirt is haired - straight and the other is curly - patterned',
#   'the person with the patterned shirt is haired - other and the curly is haired - straight',
#   'the person with the curly shirt is straight - patterned and the haired is haired - other',
#   'the person with the haired shirt is haired - straight and the curly is patterned - other',
#   'the person with the haired shirt is haired - straight and the curly is other - patterned',
#   'the person with the patterned shirt is other - straight and the curly is haired - haired',
#   'the person with the other shirt is patterned - haired and the straight is haired - curly',
#   'the person with the straight shirt is patterned - haired and the haired is other - curly',
#   'the person with the patterned shirt is haired - curly and the other is haired - straight',
#   'the person with the other shirt is patterned - haired and the haired is straight - curly',
#   'the person with the patterned shirt is other - straight and the haired is haired - curly',
#   'the person with the straight shirt is other - haired and the curly is patterned - haired',
#   'the person with the haired shirt is straight - curly and the haired is patterned - other',
#   'the person with the haired shirt is straight - curly and the haired is other - patterned',
#   'the person with the patterned shirt is other - haired and the curly is haired - straight',
#   'the person with the patterned shirt is straight - other and the haired is curly - haired',
#   'the person with the straight shirt is other - patterned and the haired is haired - curly',
#   'the person with the patterned shirt is haired - straight and the haired is curly - other',
#   'the person with the other shirt is straight - haired and the curly is haired - patterned',
#   'the person with the haired shirt is other - patterned and the haired is straight - curly',
#   'the person with the haired shirt is haired - other and the patterned is straight - curly',
#   'the person with the haired shirt is straight - curly and the patterned is haired - other',
#   'the person with the other shirt is curly - haired and the haired is patterned - straight',
#   'the person with the patterned shirt is other - haired and the curly is straight - haired',
#   'the person with the curly shirt is other - straight and the haired is patterned - haired',
#   'the person with the other shirt is haired - patterned and the straight is haired - curly',
#   'the person with the straight shirt is curly - haired and the other is patterned - haired',
#   'the person with the patterned shirt is straight - curly and the other is haired - haired',
#   'the person with the curly shirt is straight - haired and the other is haired - patterned',
#   'the person with the haired shirt is other - patterned and the haired is curly - straight',
#   'the person with the other shirt is curly - straight and the haired is patterned - haired',
#   'the person with the curly shirt is haired - patterned and the other is straight - haired',
#   'the person with the haired shirt is straight - haired and the other is curly - patterned',
#   'the person with the curly shirt is straight - patterned and the other is haired - haired',
#   'the person with the other shirt is haired - haired and the straight is curly - patterned',
#   'the person with the haired shirt is straight - other and the curly is haired - patterned',
#   'the person with the haired shirt is curly - straight and the patterned is other - haired',
#   'the person with the patterned shirt is straight - haired and the haired is other - curly',
#   'the person with the curly shirt is haired - haired and the straight is patterned - other',
#   'the person with the patterned shirt is haired - haired and the straight is curly - other',
#   'the person with the straight shirt is haired - other and the patterned is curly - haired',
#   'the person with the haired shirt is patterned - curly and the other is haired - straight',
#   'the person with the patterned shirt is haired - haired and the straight is curly - other',
#   'the person with the straight shirt is other - haired and the haired is patterned - curly',
#   'the person with the curly shirt is straight - haired and the patterned is haired - other',
#   'the person with the other shirt is patterned - straight and the haired is curly - haired',
#   'the person with the haired shirt is haired - curly and the straight is patterned - other',
#   'the person with the other shirt is curly - patterned and the straight is haired - haired',
#   'the person with the patterned shirt is haired - curly and the straight is other - haired',
# ...
#   'two people wearing clothes of the different colors are on same side of the tennis net',
#   'clothes wearing clothes two people the same colors are on different side of the tennis net',
#   'two people wearing clothes of different side are on different the same colors the tennis net',
#   'two people wearing different side of the same colors are clothes side of the tennis net',
#   'two people wearing the same colors of clothes are on different side of the tennis net',
#   'two people wearing the same clothes same colors are on different side of the tennis net',
#   'two people wearing clothes of the tennis net are on different side of the same colors',
#   'two people wearing clothes of different colors are on the same side of the tennis net'],
#  'living things drinking': ['drinking living things'],
#  'a person near water using a lasso': ['water near water a person a lasso',
#   'water near a person using a lasso',
#   'a person near a lasso water lasso',
#   'a lasso near water using a person',
#   'near a person using a water lasso'],
#  'a person spraying water on someone else and a person on a bike': ['water spraying water a person someone else and a person on a bike',
#   'a bike spraying water on someone else and a person on a person',
#   'a person spraying a person on someone else water person on a bike',
#   'a person spraying water on someone else and a bike on a person',
#   'a person spraying a bike on someone else and a person water bike',
#   'a person spraying water on a person on a bike and someone else'],
#  'a person stretching behind a brown dog': ['a brown dog stretching a person dog',
#   'a brown dog stretching behind a person'],
#  'a person carrying more than one flotation device': ['more than one a person one flotation device',
#   'more than one flotation device carrying a person'],
#  'two kids on a pool floatie and one kid swimming': ['a pool floatie two kids floatie and one kid swimming',
#   'a pool floatie on two kids and one kid swimming',
#   'two kids on one kid and one a pool floatie',
#   'one kid on a pool floatie and two kids swimming'],
#  'gears for moving something': ['moving gears for something'],
#  'looking from above at a collection of similar objects below': ['looking from above at similar objects of a collection below',
#   'looking from below at a collection of similar objects above'],
#  'a toy herbivore stands on top of at least one toy carnivore': ['a toy herbivore stands on at least one toy of top carnivore',
#   'top stands on a toy herbivore of at least one toy carnivore',
#   'at least one toy stands on top a toy herbivore toy carnivore',
#   'a toy herbivore stands on at least top least one toy carnivore',
#   'top stands on top of a toy herbivore least one toy carnivore',
#   'at least one toy herbivore stands on top of a toy carnivore'],
#  'a person supports a small chair': ['a small chair a person chair',
#   'a chair supports a small person'],
#  'a person smiles at another person wearing a checked shirt who is hitting a ping pong ball': ['a person smiles at another person wearing a ping pong ball who is a checked shirt ball',
#   'another person smiles at a person wearing a checked shirt who is hitting a ping pong ball',
#   'a checked shirt smiles at another person a person shirt who is hitting a ping pong ball',
#   'a ping pong ball smiles at another person wearing a checked shirt who a person pong ball',
#   'a person smiles at a checked shirt another person shirt who is hitting a ping pong ball',
#   'a person smiles at a ping pong ball wearing a checked shirt who another person pong ball',
#   'a person wearing a checked shirt smiles at another person who is hitting a ping pong ball'],
#  'two versions of one person': ['one person of two versions',
#   'one version of two persons'],
#  'There are not pink flowers below the bird with yellow head feathers': ['There are not the bird below pink flowers with yellow head feathers',
#   'There are not pink flowers below yellow head feathers the bird feathers',
#   'There are not yellow flowers below the bird with pink head feathers',
#   'There are not yellow head feathers below the bird pink flowers feathers',
#   'There are not yellow head feathers below the bird with pink flowers',
#   'There are pink flowers not below the bird with yellow head feathers'],
#  'In a shopping cart, there are two animals that are the same species but are looking in different directions': ['In a shopping cart , there are two animals that are different directions but are looking in different the same species',
#   'In two animals , there are two a shopping cart are the same species but are looking in different directions',
#   'In a shopping cart , there are different directions that are the same species but are looking in two animals',
#   'In a shopping cart , there are the same species that two animals species but are looking in different directions',
#   'In the same species , there are two animals that are a shopping cart but are looking in different directions',
#   'In different directions , there are two animals that are the same species but are looking in different a shopping cart',
#   'In a shopping cart , there are two animals that are the different species but are looking in same directions'],
#  'water is on and under a vessel': ['a vessel is on and water vessel',
#   'a vessel is on and under water'],
#  'two bodies share with one head': ['one head share with two bodies',
#   'one bodies share with two head'],
#  'The worker wears something striped over a white undershirt with a collar': ['The worker wears something striped over a collar with a a white undershirt',
#   'The worker wears something striped over a collar with a white undershirt',
#   'a collar wears something striped over a white undershirt with The worker',
#   'a white undershirt wears something striped The worker undershirt with a collar',
#   'The worker wears something white over a striped undershirt with a collar'],
#  'A person seen from above has a grid below them': ['a grid seen from above has A person below them',
#   'A person seen from above has them below a grid',
#   'A person seen from below has a grid above them'],
#  'head in the clouds': ['the clouds in head',
#   'the clouds head clouds',
#   'clouds in the head'],
#  'standing on feet': ['on feet standing'],
#  'They have sunglasses over their hair': ['They have their hair over sunglasses',
#   'They have their hair sunglasses hair',
#   'They have hair over their sunglasses'],
#  'an odd number of sweet things on a plate with an even number of sides': ['an odd number of sweet things on sides with an even number of sides a plate',
#   'an odd number of even things on a plate with an sweet number of sides',
#   'an odd number of sweet things on an even number a plate number of sides',
#   'sweet things of an odd number on a plate with an even number of sides',
#   'an sweet number of odd things on a plate with an even number of sides',
#   'a plate of sweet things on an odd number with an even number of sides',
#   'an odd number of sides on a plate with an even number of sides sweet things',
#   'an odd number of sweet things on a plate with sides of sides an even number',
#   'an sweet number of even things on a plate with an odd number of sides',
#   'sides of sweet things on a plate with an even number of sides an odd number',
#   'an odd number of sweet things on a plate with sides of an even number',
#   'a plate of sweet things on a an odd number an even number of sides',
#   'an odd number of a plate on sweet things with an even number of sides',
#   'sweet things of sweet an odd number a plate with an even number of sides',
#   'an odd number of an even number on a plate sweet things number of sides',
#   'an even number of odd things on a plate with an sweet number of sides',
#   'an even number of sweet things on a plate with an odd number of sides'],
#  'a large living thing in front of a large non-living thing': ['a living living thing in front of a non large - large thing',
#   'a living living thing in front of a large large non - thing',
#   'a non living thing in front of a - large large living thing',
#   'a - living thing in front of a large large living non thing',
#   'a large living thing in front of a non large - living thing',
#   'a large living thing in front of a large non living - thing',
#   'a large living thing in front of a - large non living thing',
#   'a large living thing in front of a living non - large thing',
#   'a large living thing in a large non - living thing of front',
#   'a - living thing in front of a non large living large thing',
#   'a large living thing in front of a living large non - thing',
#   'front in a large living thing of a large non - living thing',
#   'a non living thing in front of a large - large living thing',
#   'a living living thing in front of a large - large non thing',
#   'a living living thing in front of a large - non large thing',
#   'a living living thing in front of a - large large non thing',
#   'a living living thing in front of a - large non large thing',
#   'a large non - living thing in a large living thing living thing',
#   'a large living thing in front of a - non large living thing',
#   'a large living thing in front of a - large non living thing',
#   'a large living thing in front of a non living large - thing',
#   'a - living thing in front of a large living non large thing',
#   'a - living thing in front of a large non living large thing',
#   'a living living thing in front of a large non - large thing',
#   'a non living thing in front of a large living - large thing',
#   'a living living thing in front of a large - non large thing',
#   'a - living thing in front of a living large non large thing',
#   'a large living thing in front of a non - large living thing',
#   'a non living thing in front of a large large living - thing',
#   'a large living thing in front of a non - living large thing',
#   'a - living thing in front of a large large non living thing',
#   'a - living thing in front of a non large large living thing',
#   'a - living thing in front of a living large large non thing',
#   'a non living thing in front of a living large - large thing',
#   'a living living thing in front of a non large - large thing',
#   'a non living thing in front of a large living large - thing',
#   'a living living thing in front of a - large non large thing',
#   'a - living thing in front of a large living non large thing',
#   'a large living thing in front of a non - large living thing',
#   'a large living thing in front of a large living - non thing',
#   'a large living thing in front of a - living non large thing',
#   'a large living thing in front of a living - large non thing',
#   'a large living thing in front of a large living - non thing',
#   'a large living thing in front of a large - living non thing',
#   'a - living thing in front of a large non living large thing',
#   'a large living thing in front of a large - non living thing',
#   'a non living thing in front of a living large large - thing',
#   'a - living thing in front of a living large non large thing',
#   'a - living thing in front of a large large non living thing',
#   'a - living thing in front of a large living large non thing',
#   'a large living thing in front of a large - living non thing',
#   'a non living thing in front of a - large large living thing',
#   'a non living thing in front of a living large large - thing',
#   'a non living thing in front of a large large - living thing',
#   'a living living thing in front of a large large non - thing',
#   'a living living thing in front of a large large - non thing',
#   'a - living thing in front of a large non large living thing',
#   'a large living thing in front of a non - living large thing',
#   'a large living thing in front of a - large living non thing',
#   'a large living thing in front of a non living - large thing',
#   'a non living thing in front of a - large living large thing',
#   'a living living thing in front of a large non large - thing',
#   'a living living thing in front of a large non large - thing',
#   'a large living thing in front of a large non living - thing',
#   'a living living thing in front of a - non large large thing',
#   'a - living thing in front of a large large living non thing',
#   'a large living thing in front of a living non large - thing',
#   'a living living thing in front of a large large - non thing',
#   'a large living thing in front of a non large living - thing',
#   'a non living thing in front of a living - large large thing',
#   'a living living thing in front of a non large large - thing',
#   'a large living thing in front of a living large - non thing',
#   'a living living thing in front of a large - large non thing',
#   'a large living thing in a large front large non - living thing',
#   'a large living thing in front of a living - large non thing',
#   'front in front of a a large living thing non - living thing',
#   'a large living thing in front of a - non living large thing',
#   'a non living thing in front of a large living - large thing',
#   'a large living thing in front of a non large living - thing',
#   'a non living thing in front of a - living large large thing',
#   'a non living thing in front of a large - living large thing',
#   'a large living thing in front of a living - non large thing',
#   'a non living thing in front of a living - large large thing',
#   'a - living thing in front of a non living large large thing',
#   'a living living thing in front of a - large large non thing',
#   'a living living thing in front of a - non large large thing',
#   'a large living thing in front of a living non - large thing',
#   'a large living thing in front of a - living large non thing',
#   'a non living thing in front of a - living large large thing',
#   'a non living thing in front of a - large living large thing',
#   'a living living thing in front of a non large large - thing',
#   'a large living thing in front of a - living large non thing',
#   'a large living thing in front of a large - non living thing',
#   'a non living thing in front of a large living large - thing',
#   'a non living thing in front of a living large - large thing',
#   'a - living thing in front of a living non large large thing',
#   'a living living thing in front of a large non - large thing',
#   'a living living thing in front of a non - large large thing',
#   'a large living thing in front of a - non living large thing',
#   'a living living thing in front of a non - large large thing',
#   'a large living thing in front of a - living non large thing',
#   'a large living thing in front of a - large living non thing',
#   'a large living thing in front of a living large non - thing',
#   'a non living thing in front of a large large living - thing',
#   'a large living thing in front of a - non large living thing',
#   'a - living thing in front of a non living large large thing',
#   'a non living thing in front of a large large - living thing',
#   'a large living thing in front of a non living large - thing',
#   'a large living thing in front of a living - non large thing',
#   'a large living thing in front of a large living non - thing',
#   'a - living thing in front of a large non large living thing',
#   'a - living thing in front of a non large large living thing',
#   'a large living thing in front of a large living non - thing',
#   'a non living thing in front of a large - living large thing',
#   'a non living thing in front of a large - large living thing',
#   'a large living thing in front of a non living - large thing',
#   'a - living thing in front of a large living large non thing',
#   'a - living thing in front of a non large living large thing',
#   'a large living thing in front of a non large - living thing',
#   'a - living thing in front of a living non large large thing',
#   'a large living thing in front of a living non large - thing',
#   'a large living thing in front of a living large - non thing',
#   'a - living thing in front of a living large large non thing',
#   'a large non - living thing in front of a large living thing'],
#  'racing over it': ['racing it over'],
#  'someone is overdoing it': []}
